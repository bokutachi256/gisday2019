# %% [markdown]
# <a href="https://colab.research.google.com/github/bokutachi256/gisday2019/blob/master/1_%E5%9F%BA%E7%9B%A4%E5%9C%B0%E5%9B%B3%E6%83%85%E5%A0%B1%E3%81%AE%E8%AA%AD%E3%81%BF%E8%BE%BC%E3%81%BF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 基盤地図情報の読み込み

# %% [markdown]
# * GIS Day in 東京 2019 Eコース
# * Pythonを用いたDEM処理
# * 首都大学東京 都市環境学部 地理環境学科 中山大地
# * 2019年12月21日 首都大学東京 南大沢キャンパス
# * [github repository: www.github.com/bokutachi256/gisday2019](https://www.github.com/bokutachi256/gisday2019)
# * 更新履歴
#   - 2021年6月8日改訂：gdal.Warpを用いた投影変換を追加
#   - 2022年4月11日：ローカルなPython環境に対応すように改稿

# %% [markdown]
# # はじめに

# %% [markdown]
# この章では基盤地図情報の数値標高モデル（DEM: Digital Elevation Model）を用いて分析する方法について解説します．
#
# 基盤地図情報DEMを扱う上でややこしいところは以下の5点になると思います．
#
# 1. 3次メッシュ単位で1ファイルになっていること
# 1. 名前空間つきXMLになっていること
# 1. 標高値が1行に格納されていること
# 1. 標高値が固定長ではなく，省略されている場合があること
# 1. 海面のみの3次メッシュはファイル自体が存在しないこと
#
# これらを解決してメッシュ形式のDEMを取得するには様々な方法が考えられます．
#
# このテキストでは以下のこだわりでこれらの問題点を解決していきます．
#
# 1. 複数ファイルを自動的に結合する
# 1. 名前空間付きXMLをまじめに取り扱う
# 1. pandasのデータフレームを用い，縦持ちにした標高データを横持ちに変換する
# 1. `for`ループと`if`を使わない
# 1. 存在しないファイルのメッシュも自動的に補間する
#
# ネットで公開されている変換プログラムの多くは，データをメッシュ化するのにforループを使用しています．
# しかし，Pythonのforループは処理速度が遅いためできるだけ使わずに処理をしたいところです．
# 本プログラムではpandasのデータフレームを利用し，縦持ちで整理した標高データを横持ちに変換することでこの問題を解決しています．
# この方法の2次的な利点として，ファイルとして存在しないメッシュのデータや，
# 省略されているデータの処理も楽になるということも挙げられます．

# %% [markdown]
# # 計算の準備

# %% [markdown]
# ## サンプルデータの準備

# %% [markdown]
# [共有データ(https://drive.google.com/open?id=1kyhO5UU50vRfSp3BTZyy9jm2rZo8Qslp)](https://drive.google.com/open?id=1kyhO5UU50vRfSp3BTZyy9jm2rZo8Qslp)にアクセスし，
# ご自身のgoogle driveに`gisday2019`ディレクトリを作成してそこに配置してください．
#
# 講習会後にこの共有ファイルは削除します．
# このプログラムを後日試したい方は，
# [基盤地図情報サイト](https://www.gsi.go.jp/kiban/)から数値標高モデルをダウンロードしてお使いください．
# 講習会ではDEM5Aを使用しました．

# %% [markdown]
# ## ライブラリのインポート

# %% [markdown]
# 使用するライブラリを説明します．
#
# * `xml.etree.ElementTree`: XML処理用のライブラリ．
# * `numpy`: 多次元配列計算のライブラリ．
# * `matplotlib.pyplot`: グラフ作成・データ可視化ライブラリ．DEMのチェックに使用．
# * `matplotlib.colors`: カラーライブラリ．
# * `pandas`: データ処理ライブラリ．データの縦持ち・横持ち変換に使用．
# * `io`: ストリームライブラリ．標高値をデータフレームに格納するのに使用．
# * `osgeo`: 地理データ処理ライブラリ．GeoTiffの書き出しに使用．
# * `google.colab`: Google Colaboratory用ライブラリ．google driveのマウントに使用．

# %%
import xml.etree.ElementTree as ET
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import pandas as pd
import io
from osgeo import gdal, gdalconst, gdal_array, osr
#from google.colab import drive

# %% [markdown]
# ## Google Driveのマウント

# %% [markdown]
# `drive.mount`を使ってGoogle DriveをGoogle Colaboratoryにマウントします．
# `drive.mount`の引数はGoogle Colaboratory内のマウントポイントです．
# このマウントポイントで示されたディレクトリにGoogle Driveのルートディレクトリ（マイドライブ）が接続されます．
#
# `drive.mount`が実行されると，どのGoogleアカウントで接続するか聞かれます．
# 適切なアカウントを指定してアクセス権を与えます．
# その後認証コードが発行されますので，それをコピーしてテキストボックスにペーストします．
# これでGoogle Driveがマウントされます．
#
# マイドライブの中に作業用のディレクトリ`gisday2019`を作成しましたので，
# この作業用ディレクトリへのフルパスは`/drive/My Drive/gisday2019`になります．
# これを変数`base_dir`に格納しておきます．

# %%
#drive.mount('/content/drive')
#base_dir = "/content/drive/My Drive/gisday2019/"
base_dir = "./"

# %% [markdown]
# # 基盤地図情報XMLファイルについて

# %% [markdown]
# 以下が基盤地図情報DEMのXMLファイルです．

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <Dataset
#   gml:id="Dataset1"
#   xmlns="http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema"
#   xmlns:xlink="http://www.w3.org/1999/xlink"
#   xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
#   xmlns:gml="http://www.opengis.net/gml/3.2"
#   xsi:schemaLocation="http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema FGD_GMLSchema.xsd"
# >
#   <gml:description>基盤地図情報メタデータ ID=fmdid:15-3101</gml:description>
#   <gml:name>基盤地図情報ダウンロードデータ（GML版）</gml:name>
#   <DEM gml:id="DEM001">
#     <fid>fgoid:10-00100-15-60101-51390350</fid>
#     <lfSpanFr gml:id="DEM001-1">
#       <gml:timePosition>2016-10-01</gml:timePosition>
#     </lfSpanFr>
#     <devDate gml:id="DEM001-2">
#       <gml:timePosition>2016-10-01</gml:timePosition>
#     </devDate>
#     <orgGILvl>0</orgGILvl>
#     <orgMDId>H24GC009 NoData</orgMDId>
#     <type>5mメッシュ（標高）</type>
#     <mesh>51390350</mesh>
#     <coverage gml:id="DEM001-3">
#       <gml:boundedBy>
#         <gml:Envelope srsName="fguuid:jgd2011.bl">
#           <gml:lowerCorner>34.041666667 139.375</gml:lowerCorner>
#           <gml:upperCorner>34.05 139.3875</gml:upperCorner>
#         </gml:Envelope>
#       </gml:boundedBy>
#       <gml:gridDomain>
#         <gml:Grid gml:id="DEM001-4" dimension="2">
#           <gml:limits>
#             <gml:GridEnvelope>
#               <gml:low>0 0</gml:low>
#               <gml:high>224 149</gml:high>
#             </gml:GridEnvelope>
#             </gml:limits>
#             <gml:axisLabels>x y</gml:axisLabels>
#         </gml:Grid>
#       </gml:gridDomain>
#       <gml:rangeSet>
#         <gml:DataBlock>
#           <gml:rangeParameters>
#             <gml:QuantityList uom="DEM構成点"/>
#           </gml:rangeParameters>
#           <gml:tupleList>地表面,1.21 地表面,1.49. .......
#         </gml:DataBlock>
#       </gml:rangeSet>
#       <gml:coverageFunction>
#         <gml:GridFunction>
#           <gml:sequenceRule order="+x-y">Linear</gml:sequenceRule>
#           <gml:startPoint>155 12</gml:startPoint>
#         </gml:GridFunction>
#       </gml:coverageFunction>
#     </coverage>
#   </DEM>
# </Dataset>
# ```

# %% [markdown]
# ## 基盤地図情報の読み込みと扱い方

# %% [markdown]
# 基盤地図情報のXMLを読み込んでparseします．
# XMLファイルは作業用ディレクトリの`GIS-DEM`ディレクトリにコピーしてありますので．
# `base_dir + "GSI-DEM/FG-GML-5139-03-50-DEM5A-20161001.xml"`としてアクセスします．
#
# `ET.parse`を用いてxmlをパースしてから`getroot`を使ってのルート要素を取得し，`elem`に代入します．

# %%
tree = ET.parse(base_dir + "GSI-DEM/FG-GML-5338-27-00-DEM5A-20161001.xml")
elem = tree.getroot()

# %% [markdown]
# ルート要素`elem`を確認してみます．

# %%
elem
# Out:
# <Element '{http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema}Dataset' at 0x7f7f53bdcae0>

# %% [markdown]
# ルート要素のタグ`Dataset`が表示されました．

# %% [markdown]
# 次にイテレータを使ってすべてのタグを取得し，それを表示してみます．

# %%
for e in elem.getiterator():
    print(e.tag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/daichi/Documents/Dropbox/Study/Python_DEM/gisday2019/1_基盤地図情報の読み込み.ipynb Cell 25' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/daichi/Documents/Dropbox/Study/Python_DEM/gisday2019/1_%E5%9F%BA%E7%9B%A4%E5%9C%B0%E5%9B%B3%E6%83%85%E5%A0%B1%E3%81%AE%E8%AA%AD%E3%81%BF%E8%BE%BC%E3%81%BF.ipynb#ch0000024?line=0'>1</a> for e in elem.getiterator():
#       <a href='vscode-notebook-cell:/home/daichi/Documents/Dropbox/Study/Python_DEM/gisday2019/1_%E5%9F%BA%E7%9B%A4%E5%9C%B0%E5%9B%B3%E6%83%85%E5%A0%B1%E3%81%AE%E8%AA%AD%E3%81%BF%E8%BE%BC%E3%81%BF.ipynb#ch0000024?line=1'>2</a>     print(e.tag)
#
# AttributeError: 'xml.etree.ElementTree.Element' object has no attribute 'getiterator'

# %% [markdown]
# ## 名前空間付きXMLから値を取得する

# %% [markdown]
# 基盤地図情報DEMのXMLは名前空間付きXMLです．
# このため，タグへのアクセスには名前空間の接頭辞をつける必要があります．
# たとえば，`find`メソッドを使ってタグ`mesh`にアクセスする場合，
# 通常のXMLのように名前空間なしでアクセスするとエラーが発生します．

# %%
mesh = elem.find(".//mesh")
print(mesh.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/daichi/Documents/Dropbox/Study/Python_DEM/gisday2019/1_基盤地図情報の読み込み.ipynb Cell 28' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/daichi/Documents/Dropbox/Study/Python_DEM/gisday2019/1_%E5%9F%BA%E7%9B%A4%E5%9C%B0%E5%9B%B3%E6%83%85%E5%A0%B1%E3%81%AE%E8%AA%AD%E3%81%BF%E8%BE%BC%E3%81%BF.ipynb#ch0000027?line=0'>1</a> mesh = elem.find(".//mesh")
# ----> <a href='vscode-notebook-cell:/home/daichi/Documents/Dropbox/Study/Python_DEM/gisday2019/1_%E5%9F%BA%E7%9B%A4%E5%9C%B0%E5%9B%B3%E6%83%85%E5%A0%B1%E3%81%AE%E8%AA%AD%E3%81%BF%E8%BE%BC%E3%81%BF.ipynb#ch0000027?line=1'>2</a> print(mesh.text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# これを解決するためには，タグに紐づけられている名前空間のURIをタグごとに加える必要があります．
# 例えば以下のようにです．

# %%
mesh = elem.find(".//{http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema}mesh")
print(mesh.text)
# Out:
# 53382700

# %% [markdown]
# しかし，すべてのタグにURIをつけるのは煩雑です．
# プログラミングミスの原因にもなりかねません．
# もう少しエレガントな方法としては，
# タグのディクショナリをメソッドの第2引数に指定する方法があります．
#
# 以下はDEMのXMLの冒頭部です．
# xmlnsで始まる部分が名前空間の定義になっており，それぞれURIが指定されています．

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <Dataset
#   gml:id="Dataset1"
#   xmlns="http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema"
#   xmlns:xlink="http://www.w3.org/1999/xlink"
#   xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
#   xmlns:gml="http://www.opengis.net/gml/3.2"
#   xsi:schemaLocation="http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema FGD_GMLSchema.xsd"
# >
# ```

# %% [markdown]
# これを元にして名前空間の接頭辞のディクショナリを作成します．
# デフォルトの名前空間`xmlns="http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema"`については，ディクショナリのキーを`default`としています．

# %%
ns = {'default': 'http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema',
  'xlink': 'http://www.w3.org/1999/xlink',
  'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
  'gml': 'http://www.opengis.net/gml/3.2'}

# %% [markdown]
# `elem`オブジェクトの`find`メソッドにタグ`default:mesh`を入力してタ検索し，
# 値を表示してみましょう．
# 戻り値（このタグの値）は標準地域メッシュ番号となっています．
# 最初の4桁`5139`が1次メッシュコード，
# 次の2桁`03`が2次メッシュコード，
# 最後の2桁`50`が3次メッシュコードです．

# %%
mesh = elem.find('.//default:mesh', ns)
print(mesh.text)
# Out:
# 53382700

# %% [markdown]
# 次に`gml:lowerCorner`を表示してみます．
# このタグにはDEMの南西端の座標が格納されています．

# %%
lowercorner = elem.find('.//gml:lowerCorner', ns)
print(lowercorner.text)
# Out:
# 35.5 138.875

# %% [markdown]
# 同様に`gml:upperCorner`には
# 北東端の座標が格納されています．

# %%
uppercorner = elem.find('.//gml:upperCorner', ns)
print(uppercorner.text)
# Out:
# 35.508333333 138.8875

# %% [markdown]
# ## 標高値の取得とデータフレームへの格納

# %% [markdown]
# タグ`gml:tupleList`には標高が格納されています．
# 値は改行コードとカンマで分けられた文字列になっており，
# カンマの前が標高点の属性，カンマの後ろが標高値になっています．
# またデータがないメッシュの属性は`データなし`で標高値は`-9999`，
# データがあるメッシュの属性は`地表面`で標高値が実数で入っています．

# %%
tuplelist = elem.find(".//gml:tupleList", ns)
print(tuplelist.text)
# Out:
# 地表面,811.38
# 地表面,810.34
# 地表面,807.94
# 地表面,804.86
# 地表面,801.37
# 地表面,797.73
# 地表面,794.10
# 地表面,790.10
# 地表面,785.92
# 地表面,781.90
# 地表面,777.72
# 地表面,773.56
# 地表面,769.69
# 地表面,765.53
# 地表面,761.62
# 地表面,758.18
# 地表面,755.28
# 地表面,753.23
# 地表面,751.43
# 地表面,749.20
# 地表面,746.62
# 地表面,743.88
# 地表面,741.90
# 地表面,740.85
# 地表面,740.35
# 地表面,740.72
# 地表面,741.69
# 地表面,741.96
# 地表面,740.80
# 地表面,738.19
# 地表面,734.30
# 地表面,730.14
# 地表面,727.21
# 地表面,727.98
# 地表面,730.92
# 地表面,734.05
# 地表面,737.53
# 地表面,740.88
# 地表面,743.98
# 地表面,747.01
# 地表面,749.39
# 地表面,750.95
# 地表面,751.43
# 地表面,750.33
# 地表面,748.43
# 地表面,746.30
# 地表面,744.17
# 地表面,742.03
# 地表面,739.71
# 地表面,736.51
# 地表面,732.19
# 地表面,727.94
# 地表面,724.49
# 地表面,724.75
# 地表面,726.90
# 地表面,728.73
# 地表面,730.57
# 地表面,731.54
# 地表面,732.46
# 地表面,733.85
# 地表面,735.69
# 地表面,737.32
# 地表面,738.74
# 地表面,739.89
# 地表面,741.17
# 地表面,742.89
# 地表面,744.75
# 地表面,746.69
# 地表面,748.81
# 地表面,751.31
# 地表面,753.80
# 地表面,756.71
# 地表面,759.43
# 地表面,762.49
# 地表面,765.89
# 地表面,769.78
# 地表面,773.37
# 地表面,776.61
# 地表面,779.80
# 地表面,783.13
# 地表面,786.51
# 地表面,789.61
# 地表面,792.45
# 地表面,795.03
# 地表面,796.21
# 地表面,794.31
# 地表面,790.83
# 地表面,786.38
# 地表面,782.33
# 地表面,778.41
# 地表面,775.67
# 地表面,773.87
# 地表面,772.64
# 地表面,771.47
# 地表面,770.95
# 地表面,770.41
# 地表面,769.73
# 地表面,767.76
# 地表面,765.40
# 地表面,762.81
# 地表面,760.37
# 地表面,758.21
# 地表面,756.81
# 地表面,755.93
# 地表面,755.89
# 地表面,756.12
# 地表面,755.92
# 地表面,754.20
# 地表面,751.15
# 地表面,747.47
# 地表面,744.21
# 地表面,740.20
# 地表面,735.41
# 地表面,730.33
# 地表面,726.20
# 地表面,722.62
# 地表面,720.14
# 地表面,718.33
# 地表面,715.96
# 地表面,712.80
# 地表面,709.55
# 地表面,705.67
# 地表面,701.30
# 地表面,698.43
# 地表面,698.04
# 地表面,698.39
# 地表面,697.99
# 地表面,698.03
# 地表面,698.99
# 地表面,700.59
# 地表面,702.34
# 地表面,702.92
# 地表面,701.99
# 地表面,699.67
# 地表面,698.42
# 地表面,699.13
# 地表面,699.92
# 地表面,700.46
# 地表面,701.14
# 地表面,701.19
# 地表面,700.32
# 地表面,699.56
# 地表面,699.32
# 地表面,699.41
# 地表面,699.39
# 地表面,698.78
# 地表面,698.70
# 地表面,701.15
# 地表面,705.07
# 地表面,708.59
# 地表面,712.01
# 地表面,714.95
# 地表面,715.89
# 地表面,715.00
# 地表面,713.80
# 地表面,712.63
# 地表面,711.48
# 地表面,710.89
# 地表面,710.80
# 地表面,711.15
# 地表面,711.87
# 地表面,712.91
# 地表面,714.30
# 地表面,715.06
# 地表面,714.72
# 地表面,712.66
# 地表面,709.71
# 地表面,706.29
# 地表面,703.00
# 地表面,699.75
# 地表面,696.28
# 地表面,692.55
# 地表面,688.81
# 地表面,684.98
# 地表面,682.22
# 地表面,682.06
# 地表面,682.02
# 地表面,681.68
# 地表面,680.75
# 地表面,679.65
# 地表面,681.65
# 地表面,683.65
# 地表面,684.91
# 地表面,685.10
# 地表面,684.23
# 地表面,684.23
# 地表面,685.29
# 地表面,685.67
# 地表面,687.11
# 地表面,688.13
# 地表面,688.47
# 地表面,687.00
# 地表面,685.89
# 地表面,685.66
# 地表面,683.58
# 地表面,681.92
# 地表面,678.66
# 地表面,675.59
# 地表面,672.30
# 地表面,669.92
# 地表面,665.88
# 地表面,661.06
# 地表面,656.39
# 地表面,653.07
# 地表面,648.50
# 地表面,643.00
# 地表面,636.83
# 地表面,633.67
# 地表面,631.62
# 地表面,631.30
# 地表面,631.10
# 地表面,631.00
# 地表面,630.99
# 地表面,630.91
# 地表面,630.82
# 地表面,630.80
# 地表面,630.88
# 地表面,631.00
# 地表面,630.99
# 地表面,630.38
# 地表面,627.48
# 地表面,628.37
# 地表面,627.75
# 地表面,627.52
# 地表面,627.58
# 地表面,813.12
# 地表面,812.25
# 地表面,809.93
# 地表面,806.92
# 地表面,803.58
# 地表面,799.99
# 地表面,796.08
# 地表面,792.08
# 地表面,787.84
# 地表面,783.73
# 地表面,779.72
# 地表面,775.33
# 地表面,770.84
# 地表面,766.21
# 地表面,762.01
# 地表面,758.96
# 地表面,757.41
# 地表面,756.59
# 地表面,755.13
# 地表面,752.82
# 地表面,749.80
# 地表面,746.87
# 地表面,746.04
# 地表面,746.64
# 地表面,746.93
# 地表面,747.21
# 地表面,747.18
# 地表面,745.58
# 地表面,742.33
# 地表面,737.90
# 地表面,733.32
# 地表面,729.29
# 地表面,728.40
# 地表面,730.78
# 地表面,733.82
# 地表面,737.09
# 地表面,740.54
# 地表面,743.81
# 地表面,747.02
# 地表面,750.10
# 地表面,752.61
# 地表面,754.09
# 地表面,753.98
# 地表面,752.40
# 地表面,750.18
# 地表面,747.99
# 地表面,745.80
# 地表面,743.53
# 地表面,741.07
# 地表面,738.06
# 地表面,733.89
# 地表面,729.98
# 地表面,726.15
# 地表面,726.75
# 地表面,728.49
# 地表面,730.11
# 地表面,732.03
# 地表面,733.17
# 地表面,734.53
# 地表面,736.31
# 地表面,738.22
# 地表面,739.85
# 地表面,741.22
# 地表面,742.20
# 地表面,743.14
# 地表面,743.99
# 地表面,745.62
# 地表面,747.22
# 地表面,749.20
# 地表面,751.11
# 地表面,753.50
# 地表面,756.36
# 地表面,759.19
# 地表面,761.96
# 地表面,765.61
# 地表面,769.34
# 地表面,772.98
# 地表面,776.33
# 地表面,779.66
# 地表面,782.95
# 地表面,786.26
# 地表面,789.54
# 地表面,792.67
# 地表面,795.29
# 地表面,796.57
# 地表面,794.98
# 地表面,791.99
# 地表面,788.48
# 地表面,785.08
# 地表面,782.14
# 地表面,779.11
# 地表面,776.89
# 地表面,775.33
# 地表面,773.67
# 地表面,771.87
# 地表面,769.97
# 地表面,767.99
# 地表面,765.28
# 地表面,761.89
# 地表面,758.61
# 地表面,756.00
# 地表面,753.56
# 地表面,751.86
# 地表面,751.12
# 地表面,751.36
# 地表面,751.58
# 地表面,751.61
# 地表面,750.69
# 地表面,748.49
# 地表面,745.24
# 地表面,741.79
# 地表面,738.35
# 地表面,734.56
# 地表面,730.51
# 地表面,725.66
# 地表面,721.28
# 地表面,717.41
# 地表面,714.28
# 地表面,711.69
# 地表面,708.69
# 地表面,705.43
# 地表面,702.33
# 地表面,700.18
# 地表面,699.58
# 地表面,699.67
# 地表面,699.57
# 地表面,699.49
# 地表面,700.21
# 地表面,702.14
# 地表面,704.52
# 地表面,705.62
# 地表面,704.72
# 地表面,702.56
# 地表面,700.53
# 地表面,700.48
# 地表面,701.47
# 地表面,702.13
# 地表面,703.00
# 地表面,704.08
# 地表面,704.51
# 地表面,703.94
# 地表面,703.01
# 地表面,702.46
# 地表面,701.91
# 地表面,701.29
# 地表面,700.72
# 地表面,700.20
# 地表面,702.23
# 地表面,705.93
# 地表面,709.11
# 地表面,712.40
# 地表面,715.20
# 地表面,716.62
# 地表面,716.46
# 地表面,715.45
# 地表面,714.39
# 地表面,713.60
# 地表面,713.22
# 地表面,713.35
# 地表面,713.73
# 地表面,714.53
# 地表面,715.63
# 地表面,716.54
# 地表面,716.71
# 地表面,715.91
# 地表面,713.54
# 地表面,710.09
# 地表面,706.67
# 地表面,703.29
# 地表面,699.88
# 地表面,696.09
# 地表面,692.03
# 地表面,687.49
# 地表面,684.23
# 地表面,683.53
# 地表面,684.61
# 地表面,685.17
# 地表面,684.91
# 地表面,683.50
# 地表面,681.94
# 地表面,682.22
# 地表面,684.11
# 地表面,687.56
# 地表面,689.15
# 地表面,688.80
# 地表面,690.17
# 地表面,693.69
# 地表面,696.89
# 地表面,696.69
# 地表面,695.58
# 地表面,694.26
# 地表面,694.76
# 地表面,693.00
# 地表面,690.64
# 地表面,688.18
# 地表面,685.96
# 地表面,683.75
# 地表面,681.53
# 地表面,678.17
# 地表面,674.39
# 地表面,671.30
# 地表面,666.02
# 地表面,661.59
# 地表面,655.84
# 地表面,651.69
# 地表面,646.22
# 地表面,639.32
# 地表面,635.19
# 地表面,632.74
# 地表面,631.50
# 地表面,631.20
# 地表面,631.20
# 地表面,631.10
# 地表面,630.99
# 地表面,630.80
# 地表面,630.79
# 地表面,630.81
# 地表面,631.00
# 地表面,630.98
# 地表面,630.56
# 地表面,627.90
# 地表面,628.01
# 地表面,627.97
# 地表面,627.79
# 地表面,627.80
# 地表面,814.41
# 地表面,814.35
# 地表面,812.47
# 地表面,809.35
# 地表面,806.01
# 地表面,802.47
# 地表面,798.77
# 地表面,794.67
# 地表面,790.35
# 地表面,786.29
# 地表面,782.19
# 地表面,776.98
# 地表面,771.37
# 地表面,766.62
# 地表面,763.53
# 地表面,762.64
# 地表面,762.48
# 地表面,761.61
# 地表面,759.38
# 地表面,756.00
# 地表面,752.36
# 地表面,750.12
# 地表面,750.26
# 地表面,751.82
# 地表面,752.53
# 地表面,751.67
# 地表面,749.01
# 地表面,745.21
# 地表面,740.95
# 地表面,736.42
# 地表面,731.77
# 地表面,729.25
# 地表面,730.97
# 地表面,733.97
# 地表面,736.95
# 地表面,740.35
# 地表面,743.68
# 地表面,746.96
# 地表面,750.09
# 地表面,753.05
# 地表面,755.62
# 地表面,756.96
# 地表面,756.35
# 地表面,754.24
# 地表面,751.80
# 地表面,749.65
# 地表面,747.29
# 地表面,744.79
# 地表面,742.26
# 地表面,739.29
# 地表面,735.18
# 地表面,731.43
# 地表面,727.94
# 地表面,728.11
# 地表面,729.78
# 地表面,731.49
# 地表面,733.09
# 地表面,734.41
# 地表面,737.00
# 地表面,739.18
# 地表面,741.02
# 地表面,742.59
# 地表面,744.08
# 地表面,744.98
# 地表面,745.72
# 地表面,746.19
# 地表面,747.08
# 地表面,748.29
# 地表面,749.90
# 地表面,751.55
# 地表面,753.66
# 地表面,756.05
# 地表面,758.91
# 地表面,761.57
# 地表面,764.91
# 地表面,768.62
# 地表面,772.26
# 地表面,775.85
# 地表面,779.18
# 地表面,782.46
# 地表面,785.74
# 地表面,788.84
# 地表面,791.89
# 地表面,794.63
# 地表面,795.68
# 地表面,793.76
# 地表面,791.27
# 地表面,788.21
# 地表面,784.58
# 地表面,780.80
# 地表面,777.27
# 地表面,774.46
# 地表面,772.22
# 地表面,770.20
# 地表面,767.60
# 地表面,765.52
# 地表面,763.95
# 地表面,761.90
# 地表面,758.01
# 地表面,753.83
# 地表面,750.83
# 地表面,748.57
# 地表面,746.48
# 地表面,745.65
# 地表面,746.17
# 地表面,746.84
# 地表面,747.12
# 地表面,746.62
# 地表面,745.07
# 地表面,742.30
# 地表面,739.08
# 地表面,735.76
# 地表面,732.12
# 地表面,728.45
# 地表面,724.47
# 地表面,720.28
# 地表面,715.90
# 地表面,711.84
# 地表面,708.40
# 地表面,704.96
# 地表面,702.14
# 地表面,701.50
# 地表面,701.90
# 地表面,701.56
# 地表面,701.24
# 地表面,701.15
# 地表面,701.37
# 地表面,702.65
# 地表面,705.05
# 地表面,707.05
# 地表面,707.19
# 地表面,705.43
# 地表面,703.05
# 地表面,701.78
# 地表面,702.48
# 地表面,703.38
# 地表面,704.40
# 地表面,705.98
# 地表面,707.36
# 地表面,707.83
# 地表面,707.17
# 地表面,705.82
# 地表面,704.79
# 地表面,703.90
# 地表面,703.10
# 地表面,702.90
# 地表面,702.13
# 地表面,703.10
# 地表面,706.37
# 地表面,709.47
# 地表面,712.54
# 地表面,715.31
# 地表面,717.30
# 地表面,717.73
# 地表面,717.04
# 地表面,716.26
# 地表面,715.72
# 地表面,715.59
# 地表面,715.89
# 地表面,716.40
# 地表面,717.26
# 地表面,718.16
# 地表面,718.68
# 地表面,718.48
# 地表面,717.09
# 地表面,714.10
# 地表面,710.42
# 地表面,707.01
# 地表面,703.75
# 地表面,700.20
# 地表面,696.20
# 地表面,692.33
# 地表面,688.23
# 地表面,685.60
# 地表面,686.08
# 地表面,687.76
# 地表面,689.08
# 地表面,688.67
# 地表面,686.88
# 地表面,685.01
# 地表面,683.96
# 地表面,684.95
# 地表面,688.00
# 地表面,690.60
# 地表面,691.71
# 地表面,694.10
# 地表面,698.19
# 地表面,702.79
# 地表面,704.92
# 地表面,705.06
# 地表面,705.48
# 地表面,705.05
# 地表面,703.48
# 地表面,698.71
# 地表面,693.91
# 地表面,689.60
# 地表面,687.25
# 地表面,684.83
# 地表面,682.33
# 地表面,679.17
# 地表面,675.16
# 地表面,671.55
# 地表面,665.63
# 地表面,659.47
# 地表面,652.74
# 地表面,647.07
# 地表面,640.29
# 地表面,636.20
# 地表面,633.85
# 地表面,631.73
# 地表面,631.45
# 地表面,631.37
# 地表面,631.24
# 地表面,631.11
# 地表面,630.91
# 地表面,630.72
# 地表面,630.69
# 地表面,630.67
# 地表面,630.52
# 地表面,629.40
# 地表面,628.57
# 地表面,628.37
# 地表面,628.25
# 地表面,628.14
# 地表面,627.99
# 地表面,814.99
# 地表面,815.65
# 地表面,814.50
# 地表面,812.04
# 地表面,808.83
# 地表面,805.32
# 地表面,801.42
# 地表面,797.24
# 地表面,792.66
# 地表面,787.90
# 地表面,783.15
# 地表面,777.70
# 地表面,772.17
# 地表面,768.78
# 地表面,767.94
# 地表面,768.10
# 地表面,767.82
# 地表面,765.99
# 地表面,762.66
# 地表面,758.71
# 地表面,755.49
# 地表面,754.17
# 地表面,755.05
# 地表面,756.23
# 地表面,755.95
# 地表面,753.21
# 地表面,748.86
# 地表面,744.40
# 地表面,740.14
# 地表面,735.62
# 地表面,731.49
# 地表面,731.06
# 地表面,733.36
# 地表面,736.09
# 地表面,739.39
# 地表面,743.08
# 地表面,746.59
# 地表面,750.08
# 地表面,753.41
# 地表面,756.43
# 地表面,758.79
# 地表面,759.64
# 地表面,758.21
# 地表面,755.89
# 地表面,753.42
# 地表面,751.12
# 地表面,748.48
# 地表面,745.88
# 地表面,743.19
# 地表面,740.29
# 地表面,736.41
# 地表面,732.76
# 地表面,729.43
# 地表面,729.32
# 地表面,731.27
# 地表面,732.94
# 地表面,735.10
# 地表面,737.20
# 地表面,739.38
# 地表面,741.58
# 地表面,743.64
# 地表面,745.49
# 地表面,747.20
# 地表面,748.41
# 地表面,748.67
# 地表面,748.92
# 地表面,749.04
# 地表面,749.78
# 地表面,750.83
# 地表面,752.38
# 地表面,754.25
# 地表面,756.26
# 地表面,758.72
# 地表面,761.69
# 地表面,764.34
# 地表面,767.91
# 地表面,771.63
# 地表面,775.27
# 地表面,778.70
# 地表面,781.74
# 地表面,784.76
# 地表面,787.89
# 地表面,790.91
# 地表面,793.52
# 地表面,794.46
# 地表面,792.44
# 地表面,789.99
# 地表面,786.64
# 地表面,782.53
# 地表面,778.51
# 地表面,774.53
# 地表面,771.11
# 地表面,767.54
# 地表面,764.97
# 地表面,762.44
# 地表面,759.85
# 地表面,758.16
# 地表面,757.61
# 地表面,755.45
# 地表面,751.17
# 地表面,747.36
# 地表面,744.16
# 地表面,741.74
# 地表面,740.46
# 地表面,740.65
# 地表面,741.50
# 地表面,742.38
# 地表面,742.55
# 地表面,741.39
# 地表面,739.12
# 地表面,736.11
# 地表面,733.03
# 地表面,729.51
# 地表面,725.97
# 地表面,722.16
# 地表面,717.60
# 地表面,713.05
# 地表面,708.98
# 地表面,705.83
# 地表面,703.17
# 地表面,702.49
# 地表面,703.47
# 地表面,703.51
# 地表面,703.46
# 地表面,703.63
# 地表面,703.56
# 地表面,703.59
# 地表面,704.70
# 地表面,707.00
# 地表面,708.57
# 地表面,707.98
# 地表面,705.61
# 地表面,703.51
# 地表面,703.54
# 地表面,704.73
# 地表面,705.96
# 地表面,707.59
# 地表面,709.29
# 地表面,710.61
# 地表面,710.98
# 地表面,710.09
# 地表面,708.25
# 地表面,706.74
# 地表面,705.67
# 地表面,704.78
# 地表面,704.75
# 地表面,704.32
# 地表面,703.70
# 地表面,706.00
# 地表面,709.88
# 地表面,712.88
# 地表面,715.58
# 地表面,717.80
# 地表面,718.70
# 地表面,718.44
# 地表面,717.99
# 地表面,717.76
# 地表面,717.87
# 地表面,718.35
# 地表面,719.00
# 地表面,719.85
# 地表面,720.56
# 地表面,720.93
# 地表面,720.19
# 地表面,717.77
# 地表面,714.32
# 地表面,710.64
# 地表面,707.21
# 地表面,703.87
# 地表面,700.29
# 地表面,696.33
# 地表面,692.51
# 地表面,688.47
# 地表面,687.61
# 地表面,689.14
# 地表面,691.24
# 地表面,693.03
# 地表面,692.78
# 地表面,690.10
# 地表面,687.54
# 地表面,686.31
# 地表面,685.83
# 地表面,688.12
# 地表面,690.76
# 地表面,693.37
# 地表面,696.98
# 地表面,701.41
# 地表面,705.66
# 地表面,708.97
# 地表面,711.70
# 地表面,713.07
# 地表面,711.39
# 地表面,709.05
# 地表面,705.77
# 地表面,699.92
# 地表面,695.07
# 地表面,691.80
# 地表面,689.19
# 地表面,686.57
# 地表面,683.71
# 地表面,680.70
# 地表面,677.20
# 地表面,671.77
# 地表面,659.53
# 地表面,652.66
# 地表面,645.67
# 地表面,639.03
# 地表面,636.66
# 地表面,635.34
# 地表面,633.18
# 地表面,632.05
# 地表面,632.35
# 地表面,631.44
# 地表面,631.24
# 地表面,631.03
# 地表面,630.84
# 地表面,630.73
# 地表面,630.51
# 地表面,630.00
# 地表面,629.49
# 地表面,629.05
# 地表面,628.76
# 地表面,628.53
# 地表面,628.48
# 地表面,628.42
# 地表面,815.06
# 地表面,816.42
# 地表面,816.17
# 地表面,814.05
# 地表面,810.82
# 地表面,806.94
# 地表面,802.38
# 地表面,797.95
# 地表面,793.41
# 地表面,788.55
# 地表面,783.41
# 地表面,778.40
# 地表面,775.41
# 地表面,774.90
# 地表面,774.81
# 地表面,774.01
# 地表面,772.22
# 地表面,769.36
# 地表面,765.65
# 地表面,762.04
# 地表面,759.76
# 地表面,759.17
# 地表面,760.12
# 地表面,760.25
# 地表面,757.90
# 地表面,753.93
# 地表面,749.58
# 地表面,745.00
# 地表面,740.60
# 地表面,736.14
# 地表面,732.59
# 地表面,733.13
# 地表面,735.90
# 地表面,738.24
# 地表面,741.02
# 地表面,744.89
# 地表面,748.93
# 地表面,752.85
# 地表面,756.36
# 地表面,759.54
# 地表面,761.75
# 地表面,761.80
# 地表面,760.03
# 地表面,757.44
# 地表面,754.83
# 地表面,752.21
# 地表面,749.37
# 地表面,746.66
# 地表面,743.84
# 地表面,740.75
# 地表面,737.12
# 地表面,733.67
# 地表面,730.54
# 地表面,731.35
# 地表面,733.19
# 地表面,734.94
# 地表面,737.33
# 地表面,739.73
# 地表面,741.95
# 地表面,744.10
# 地表面,746.30
# 地表面,748.33
# 地表面,750.08
# 地表面,751.50
# 地表面,752.08
# 地表面,752.27
# 地表面,752.16
# 地表面,751.88
# 地表面,752.30
# 地表面,753.49
# 地表面,755.05
# 地表面,757.05
# 地表面,759.09
# 地表面,761.41
# 地表面,764.15
# 地表面,767.40
# 地表面,770.96
# 地表面,774.59
# 地表面,777.93
# 地表面,780.87
# 地表面,783.84
# 地表面,786.97
# 地表面,789.99
# 地表面,792.07
# 地表面,792.78
# 地表面,791.00
# 地表面,787.97
# 地表面,784.46
# 地表面,780.99
# 地表面,777.19
# 地表面,773.08
# 地表面,768.93
# 地表面,764.21
# 地表面,760.63
# 地表面,757.95
# 地表面,755.03
# 地表面,753.07
# 地表面,752.70
# 地表面,752.29
# 地表面,750.70
# 地表面,747.06
# 地表面,742.56
# 地表面,739.14
# 地表面,736.31
# 地表面,735.44
# 地表面,736.26
# 地表面,737.12
# 地表面,737.86
# 地表面,737.45
# 地表面,735.29
# 地表面,732.78
# 地表面,729.77
# 地表面,726.78
# 地表面,723.32
# 地表面,719.50
# 地表面,715.26
# 地表面,710.69
# 地表面,706.86
# 地表面,704.63
# 地表面,703.27
# 地表面,704.15
# 地表面,704.74
# 地表面,705.22
# 地表面,706.30
# 地表面,707.10
# 地表面,707.23
# 地表面,706.84
# 地表面,707.06
# 地表面,708.73
# 地表面,709.74
# 地表面,708.47
# 地表面,705.86
# 地表面,704.44
# 地表面,705.79
# 地表面,707.87
# 地表面,709.65
# 地表面,711.34
# 地表面,712.96
# 地表面,713.99
# 地表面,713.89
# 地表面,712.60
# 地表面,710.55
# 地表面,708.56
# 地表面,707.34
# 地表面,706.48
# 地表面,706.03
# 地表面,705.82
# 地表面,705.39
# 地表面,706.51
# 地表面,709.97
# 地表面,713.36
# 地表面,715.97
# 地表面,718.21
# 地表面,719.63
# 地表面,719.97
# 地表面,719.79
# 地表面,719.81
# 地表面,720.23
# 地表面,720.77
# 地表面,721.51
# 地表面,722.58
# 地表面,723.15
# 地表面,722.88
# 地表面,720.99
# 地表面,717.98
# 地表面,714.48
# 地表面,710.54
# 地表面,706.74
# 地表面,703.47
# 地表面,699.94
# 地表面,696.44
# 地表面,692.23
# 地表面,689.06
# 地表面,689.55
# 地表面,691.71
# 地表面,694.29
# 地表面,696.50
# 地表面,695.98
# 地表面,692.41
# 地表面,689.52
# 地表面,688.13
# 地表面,687.12
# 地表面,688.36
# 地表面,691.14
# 地表面,694.37
# 地表面,698.61
# 地表面,703.23
# 地表面,707.05
# 地表面,710.73
# 地表面,714.44
# 地表面,717.66
# 地表面,717.77
# 地表面,713.60
# 地表面,708.89
# 地表面,704.50
# 地表面,700.76
# 地表面,697.95
# 地表面,695.38
# 地表面,692.69
# 地表面,689.49
# 地表面,686.31
# 地表面,682.75
# 地表面,676.23
# 地表面,655.34
# 地表面,649.28
# 地表面,642.84
# 地表面,639.00
# 地表面,637.51
# 地表面,635.01
# 地表面,634.20
# 地表面,632.93
# 地表面,633.39
# 地表面,632.66
# 地表面,631.35
# 地表面,631.08
# 地表面,630.89
# 地表面,630.78
# 地表面,630.61
# 地表面,630.27
# 地表面,629.87
# 地表面,629.51
# 地表面,628.95
# 地表面,628.80
# 地表面,628.80
# 地表面,628.78
# 地表面,814.79
# 地表面,816.52
# 地表面,817.07
# 地表面,815.52
# 地表面,812.28
# 地表面,808.09
# 地表面,803.33
# 地表面,798.73
# 地表面,794.30
# 地表面,789.76
# 地表面,785.09
# 地表面,782.43
# 地表面,781.83
# 地表面,781.60
# 地表面,780.48
# 地表面,778.32
# 地表面,775.46
# 地表面,772.08
# 地表面,768.72
# 地表面,766.20
# 地表面,764.89
# 地表面,764.95
# 地表面,765.28
# 地表面,763.42
# 地表面,759.83
# 地表面,755.76
# 地表面,751.23
# 地表面,746.76
# 地表面,742.44
# 地表面,737.66
# 地表面,734.17
# 地表面,735.60
# 地表面,739.43
# 地表面,742.42
# 地表面,744.31
# 地表面,746.73
# 地表面,750.62
# 地表面,755.04
# 地表面,759.05
# 地表面,762.51
# 地表面,764.35
# 地表面,763.74
# 地表面,761.45
# 地表面,758.68
# 地表面,755.79
# 地表面,753.06
# 地表面,749.95
# 地表面,746.92
# 地表面,743.84
# 地表面,740.60
# 地表面,737.27
# 地表面,733.43
# 地表面,731.57
# 地表面,732.94
# 地表面,734.92
# 地表面,737.21
# 地表面,739.96
# 地表面,742.17
# 地表面,744.36
# 地表面,746.62
# 地表面,748.81
# 地表面,750.92
# 地表面,752.95
# 地表面,754.58
# 地表面,755.30
# 地表面,755.54
# 地表面,755.02
# 地表面,754.76
# 地表面,754.64
# 地表面,755.11
# 地表面,756.21
# 地表面,757.74
# 地表面,759.62
# 地表面,761.73
# 地表面,764.18
# 地表面,766.99
# 地表面,770.35
# 地表面,773.68
# 地表面,776.96
# 地表面,779.71
# 地表面,782.58
# 地表面,785.66
# 地表面,788.58
# 地表面,790.22
# 地表面,790.58
# 地表面,788.59
# 地表面,785.50
# 地表面,781.85
# 地表面,778.04
# 地表面,774.01
# 地表面,770.46
# 地表面,766.97
# 地表面,762.04
# 地表面,758.21
# 地表面,754.44
# 地表面,751.16
# 地表面,748.83
# 地表面,747.70
# 地表面,746.93
# 地表面,746.31
# 地表面,744.97
# 地表面,742.08
# 地表面,738.01
# 地表面,733.68
# 地表面,731.35
# 地表面,731.69
# 地表面,732.66
# 地表面,733.58
# 地表面,733.56
# 地表面,731.49
# 地表面,728.86
# 地表面,726.34
# 地表面,723.59
# 地表面,720.51
# 地表面,716.93
# 地表面,713.01
# 地表面,709.27
# 地表面,706.52
# 地表面,704.70
# 地表面,705.24
# 地表面,706.43
# 地表面,706.28
# 地表面,707.55
# 地表面,709.58
# 地表面,710.46
# 地表面,710.16
# 地表面,709.54
# 地表面,709.74
# 地表面,710.74
# 地表面,710.62
# 地表面,708.67
# 地表面,706.56
# 地表面,706.97
# 地表面,709.45
# 地表面,711.66
# 地表面,713.74
# 地表面,715.33
# 地表面,716.54
# 地表面,717.22
# 地表面,716.68
# 地表面,714.91
# 地表面,712.61
# 地表面,710.49
# 地表面,708.98
# 地表面,707.98
# 地表面,707.83
# 地表面,708.12
# 地表面,707.85
# 地表面,708.50
# 地表面,711.05
# 地表面,713.88
# 地表面,716.58
# 地表面,719.03
# 地表面,720.61
# 地表面,721.52
# 地表面,722.07
# 地表面,722.44
# 地表面,722.65
# 地表面,723.14
# 地表面,724.11
# 地表面,725.28
# 地表面,725.50
# 地表面,724.02
# 地表面,721.19
# 地表面,717.83
# 地表面,714.15
# 地表面,710.40
# 地表面,706.75
# 地表面,703.32
# 地表面,699.59
# 地表面,695.93
# 地表面,691.97
# 地表面,690.25
# 地表面,691.78
# 地表面,694.30
# 地表面,697.03
# 地表面,699.19
# 地表面,697.88
# 地表面,694.16
# 地表面,690.96
# 地表面,689.53
# 地表面,688.33
# 地表面,689.11
# 地表面,692.35
# 地表面,696.94
# 地表面,700.86
# 地表面,704.51
# 地表面,708.12
# 地表面,711.90
# 地表面,715.55
# 地表面,718.63
# 地表面,719.81
# 地表面,716.83
# 地表面,712.17
# 地表面,708.33
# 地表面,705.86
# 地表面,704.06
# 地表面,701.03
# 地表面,697.44
# 地表面,692.96
# 地表面,688.61
# 地表面,684.28
# 地表面,676.67
# 地表面,652.98
# 地表面,645.96
# 地表面,641.46
# 地表面,640.95
# 地表面,639.53
# 地表面,636.30
# 地表面,633.34
# 地表面,633.66
# 地表面,633.23
# 地表面,633.64
# 地表面,632.91
# 地表面,631.18
# 地表面,630.98
# 地表面,630.89
# 地表面,630.86
# 地表面,630.66
# 地表面,630.46
# 地表面,629.65
# 地表面,629.26
# 地表面,629.16
# 地表面,629.08
# 地表面,629.06
# 地表面,814.60
# 地表面,816.40
# 地表面,817.47
# 地表面,816.57
# 地表面,813.38
# 地表面,809.34
# 地表面,805.30
# 地表面,801.00
# 地表面,796.82
# 地表面,793.00
# 地表面,790.12
# 地表面,789.40
# 地表面,788.96
# 地表面,787.74
# 地表面,785.19
# 地表面,781.51
# 地表面,777.90
# 地表面,774.81
# 地表面,772.53
# 地表面,771.27
# 地表面,771.11
# 地表面,771.12
# 地表面,769.83
# 地表面,766.82
# 地表面,762.82
# 地表面,758.80
# 地表面,754.47
# 地表面,750.11
# 地表面,745.04
# 地表面,739.98
# 地表面,736.26
# 地表面,737.35
# 地表面,742.17
# 地表面,746.69
# 地表面,749.24
# 地表面,750.65
# 地表面,753.45
# 地表面,757.56
# 地表面,761.75
# 地表面,765.20
# 地表面,766.35
# 地表面,765.07
# 地表面,762.44
# 地表面,759.24
# 地表面,755.70
# 地表面,752.49
# 地表面,749.30
# 地表面,746.10
# 地表面,743.18
# 地表面,740.10
# 地表面,737.08
# 地表面,733.30
# 地表面,732.72
# 地表面,734.94
# 地表面,737.32
# 地表面,739.79
# 地表面,742.38
# 地表面,744.39
# 地表面,746.62
# 地表面,749.00
# 地表面,751.25
# 地表面,753.50
# 地表面,755.62
# 地表面,757.67
# 地表面,758.65
# 地表面,758.97
# 地表面,758.67
# 地表面,757.92
# 地表面,757.38
# 地表面,757.38
# 地表面,757.89
# 地表面,759.07
# 地表面,760.47
# 地表面,762.34
# 地表面,764.42
# 地表面,766.85
# 地表面,769.73
# 地表面,772.70
# 地表面,776.20
# 地表面,778.73
# 地表面,781.31
# 地表面,784.19
# 地表面,786.72
# 地表面,788.50
# 地表面,788.34
# 地表面,785.83
# 地表面,782.09
# 地表面,778.08
# 地表面,774.30
# 地表面,770.06
# 地表面,766.45
# 地表面,763.32
# 地表面,759.97
# 地表面,756.12
# 地表面,752.28
# 地表面,748.63
# 地表面,745.56
# 地表面,742.83
# 地表面,741.38
# 地表面,741.60
# 地表面,741.01
# 地表面,739.61
# 地表面,736.63
# 地表面,732.69
# 地表面,729.04
# 地表面,726.94
# 地表面,727.70
# 地表面,729.05
# 地表面,729.43
# 地表面,727.66
# 地表面,725.22
# 地表面,722.81
# 地表面,720.02
# 地表面,717.08
# 地表面,713.94
# 地表面,710.71
# 地表面,708.07
# 地表面,706.43
# 地表面,705.87
# 地表面,706.71
# 地表面,707.65
# 地表面,709.12
# 地表面,712.12
# 地表面,713.81
# 地表面,713.99
# 地表面,713.07
# 地表面,712.38
# 地表面,712.23
# 地表面,712.37
# 地表面,711.12
# 地表面,708.39
# 地表面,707.86
# 地表面,710.93
# 地表面,714.01
# 地表面,716.04
# 地表面,717.86
# 地表面,719.49
# 地表面,720.52
# 地表面,720.58
# 地表面,719.34
# 地表面,717.07
# 地表面,714.47
# 地表面,712.10
# 地表面,710.51
# 地表面,709.80
# 地表面,709.90
# 地表面,710.18
# 地表面,709.35
# 地表面,709.47
# 地表面,711.96
# 地表面,714.96
# 地表面,717.67
# 地表面,720.03
# 地表面,721.89
# 地表面,723.22
# 地表面,724.02
# 地表面,724.57
# 地表面,725.22
# 地表面,726.00
# 地表面,726.77
# 地表面,727.39
# 地表面,727.04
# 地表面,724.92
# 地表面,721.43
# 地表面,717.82
# 地表面,714.28
# 地表面,710.70
# 地表面,707.01
# 地表面,703.59
# 地表面,699.79
# 地表面,695.88
# 地表面,693.12
# 地表面,691.94
# 地表面,693.98
# 地表面,697.13
# 地表面,699.86
# 地表面,701.52
# 地表面,699.71
# 地表面,695.98
# 地表面,692.87
# 地表面,691.39
# 地表面,689.85
# 地表面,691.47
# 地表面,694.76
# 地表面,698.80
# 地表面,702.94
# 地表面,706.86
# 地表面,710.34
# 地表面,713.71
# 地表面,717.15
# 地表面,719.68
# 地表面,720.42
# 地表面,717.47
# 地表面,713.95
# 地表面,710.82
# 地表面,708.07
# 地表面,704.81
# 地表面,700.89
# 地表面,696.74
# 地表面,691.08
# 地表面,686.30
# 地表面,681.66
# 地表面,670.35
# 地表面,652.25
# 地表面,645.86
# 地表面,643.55
# 地表面,642.58
# 地表面,640.86
# 地表面,639.04
# 地表面,635.68
# 地表面,633.11
# 地表面,632.50
# 地表面,632.43
# 地表面,632.71
# 地表面,633.22
# 地表面,632.22
# 地表面,631.56
# 地表面,631.35
# 地表面,631.24
# 地表面,630.78
# 地表面,629.66
# 地表面,629.76
# 地表面,629.70
# 地表面,629.89
# 地表面,629.64
# 地表面,814.84
# 地表面,816.40
# 地表面,817.67
# 地表面,817.57
# 地表面,815.54
# 地表面,812.08
# 地表面,808.01
# 地表面,804.23
# 地表面,800.88
# 地表面,798.23
# 地表面,796.61
# 地表面,795.59
# 地表面,794.01
# 地表面,791.68
# 地表面,788.37
# 地表面,784.23
# 地表面,780.64
# 地表面,778.31
# 地表面,776.88
# 地表面,776.24
# 地表面,776.20
# 地表面,775.48
# 地表面,772.73
# 地表面,768.67
# 地表面,764.32
# 地表面,760.16
# 地表面,755.89
# 地表面,751.67
# 地表面,746.51
# 地表面,740.99
# 地表面,737.95
# 地表面,739.50
# 地表面,744.17
# 地表面,748.86
# 地表面,752.74
# 地表面,755.45
# 地表面,757.91
# 地表面,761.16
# 地表面,764.55
# 地表面,767.39
# 地表面,767.55
# 地表面,765.13
# 地表面,761.76
# 地表面,758.17
# 地表面,754.81
# 地表面,751.46
# 地表面,748.33
# 地表面,745.09
# 地表面,742.22
# 地表面,739.37
# 地表面,736.60
# 地表面,733.95
# 地表面,735.13
# 地表面,737.49
# 地表面,739.65
# 地表面,741.99
# 地表面,744.48
# 地表面,746.51
# 地表面,748.83
# 地表面,751.16
# 地表面,753.39
# 地表面,755.77
# 地表面,758.01
# 地表面,760.31
# 地表面,762.08
# 地表面,762.36
# 地表面,762.09
# 地表面,761.41
# 地表面,760.52
# 地表面,760.07
# 地表面,759.95
# 地表面,760.43
# 地表面,761.78
# 地表面,763.20
# 地表面,765.00
# 地表面,767.21
# 地表面,769.73
# 地表面,772.36
# 地表面,775.04
# 地表面,777.94
# 地表面,780.37
# 地表面,782.91
# 地表面,785.50
# 地表面,787.13
# 地表面,785.66
# 地表面,782.54
# 地表面,778.39
# 地表面,773.66
# 地表面,769.70
# 地表面,765.98
# 地表面,762.67
# 地表面,759.02
# 地表面,756.18
# 地表面,753.01
# 地表面,749.36
# 地表面,745.84
# 地表面,743.54
# 地表面,740.61
# 地表面,736.89
# 地表面,735.38
# 地表面,735.75
# 地表面,735.32
# 地表面,733.16
# 地表面,730.19
# 地表面,727.10
# 地表面,723.80
# 地表面,723.76
# 地表面,724.98
# 地表面,725.16
# 地表面,723.43
# 地表面,721.04
# 地表面,718.60
# 地表面,716.04
# 地表面,713.51
# 地表面,710.77
# 地表面,708.76
# 地表面,707.65
# 地表面,706.60
# 地表面,707.24
# 地表面,709.43
# 地表面,711.13
# 地表面,713.32
# 地表面,716.52
# 地表面,717.96
# 地表面,717.47
# 地表面,715.72
# 地表面,714.69
# 地表面,714.19
# 地表面,713.55
# 地表面,711.24
# 地表面,709.43
# 地表面,711.35
# 地表面,715.17
# 地表面,718.17
# 地表面,720.11
# 地表面,721.84
# 地表面,723.31
# 地表面,723.96
# 地表面,723.53
# 地表面,721.81
# 地表面,719.22
# 地表面,716.34
# 地表面,713.76
# 地表面,711.87
# 地表面,711.37
# 地表面,711.92
# 地表面,712.05
# 地表面,710.77
# 地表面,710.91
# 地表面,713.38
# 地表面,716.10
# 地表面,718.69
# 地表面,721.13
# 地表面,723.36
# 地表面,725.30
# 地表面,726.59
# 地表面,727.40
# 地表面,728.01
# 地表面,728.57
# 地表面,729.24
# 地表面,729.62
# 地表面,728.33
# 地表面,725.52
# 地表面,721.86
# 地表面,718.27
# 地表面,714.92
# 地表面,711.58
# 地表面,707.83
# 地表面,704.53
# 地表面,701.26
# 地表面,698.26
# 地表面,695.88
# 地表面,694.09
# 地表面,696.02
# 地表面,699.42
# 地表面,702.40
# 地表面,703.64
# 地表面,701.48
# 地表面,697.64
# 地表面,694.51
# 地表面,692.86
# 地表面,691.26
# 地表面,693.28
# 地表面,696.69
# 地表面,700.67
# 地表面,704.94
# 地表面,709.19
# 地表面,713.04
# 地表面,716.42
# 地表面,719.39
# 地表面,721.42
# 地表面,719.38
# 地表面,715.26
# 地表面,710.49
# 地表面,706.18
# 地表面,703.12
# 地表面,700.10
# 地表面,695.91
# 地表面,692.46
# 地表面,688.34
# 地表面,684.13
# 地表面,678.93
# 地表面,666.37
# 地表面,652.36
# 地表面,647.65
# 地表面,645.60
# 地表面,644.52
# 地表面,642.53
# 地表面,640.46
# 地表面,637.89
# 地表面,636.23
# 地表面,634.40
# 地表面,633.79
# 地表面,633.04
# 地表面,632.85
# 地表面,633.02
# 地表面,632.97
# 地表面,632.26
# 地表面,631.92
# 地表面,631.33
# 地表面,630.25
# 地表面,630.29
# 地表面,630.30
# 地表面,631.37
# 地表面,631.26
# 地表面,815.70
# 地表面,816.98
# 地表面,818.18
# 地表面,818.68
# 地表面,817.83
# 地表面,815.42
# 地表面,812.19
# 地表面,808.93
# 地表面,805.89
# 地表面,803.89
# 地表面,802.29
# 地表面,800.27
# 地表面,797.69
# 地表面,794.51
# 地表面,790.90
# 地表面,787.39
# 地表面,784.51
# 地表面,782.49
# 地表面,781.33
# 地表面,780.31
# 地表面,778.55
# 地表面,775.64
# 地表面,771.97
# 地表面,767.83
# 地表面,763.38
# 地表面,759.01
# 地表面,754.75
# 地表面,750.71
# 地表面,746.02
# 地表面,741.15
# 地表面,739.75
# 地表面,742.41
# 地表面,746.17
# 地表面,750.21
# 地表面,754.81
# 地表面,759.24
# 地表面,762.58
# 地表面,765.50
# 地表面,767.86
# 地表面,769.10
# 地表面,767.46
# 地表面,764.22
# 地表面,760.83
# 地表面,757.33
# 地表面,753.84
# 地表面,750.72
# 地表面,747.51
# 地表面,744.39
# 地表面,741.65
# 地表面,739.14
# 地表面,736.33
# 地表面,735.81
# 地表面,738.11
# 地表面,740.19
# 地表面,741.90
# 地表面,744.04
# 地表面,746.48
# 地表面,748.76
# 地表面,750.95
# 地表面,753.07
# 地表面,755.44
# 地表面,757.91
# 地表面,760.45
# 地表面,762.57
# 地表面,764.56
# 地表面,765.68
# 地表面,765.58
# 地表面,765.00
# 地表面,764.09
# 地表面,763.20
# 地表面,762.92
# 地表面,763.10
# 地表面,763.43
# 地表面,764.62
# 地表面,766.25
# 地表面,768.00
# 地表面,770.34
# 地表面,772.45
# 地表面,774.68
# 地表面,777.41
# 地表面,779.66
# 地表面,782.18
# 地表面,784.68
# 地表面,786.30
# 地表面,784.66
# 地表面,780.20
# 地表面,775.41
# 地表面,771.04
# 地表面,766.93
# 地表面,763.33
# 地表面,759.58
# 地表面,755.78
# 地表面,752.39
# 地表面,749.31
# 地表面,746.09
# 地表面,742.85
# 地表面,739.62
# 地表面,737.00
# 地表面,734.44
# 地表面,731.00
# 地表面,730.44
# 地表面,730.62
# 地表面,729.18
# 地表面,726.71
# 地表面,723.62
# 地表面,721.13
# 地表面,720.40
# 地表面,720.76
# 地表面,720.26
# 地表面,718.88
# 地表面,716.57
# 地表面,714.18
# 地表面,712.10
# 地表面,710.60
# 地表面,709.82
# 地表面,708.88
# 地表面,707.81
# 地表面,708.50
# 地表面,711.14
# 地表面,714.08
# 地表面,716.57
# 地表面,718.60
# 地表面,720.29
# 地表面,721.18
# 地表面,719.92
# 地表面,717.86
# 地表面,716.64
# 地表面,715.84
# 地表面,714.26
# 地表面,711.66
# 地表面,711.73
# 地表面,715.15
# 地表面,718.87
# 地表面,721.63
# 地表面,723.89
# 地表面,725.76
# 地表面,726.92
# 地表面,727.16
# 地表面,726.30
# 地表面,724.31
# 地表面,721.69
# 地表面,718.57
# 地表面,715.61
# 地表面,713.51
# 地表面,713.04
# 地表面,713.60
# 地表面,713.62
# 地表面,712.13
# 地表面,712.36
# 地表面,714.97
# 地表面,717.47
# 地表面,720.02
# 地表面,722.55
# 地表面,725.12
# 地表面,727.49
# 地表面,729.18
# 地表面,730.09
# 地表面,730.75
# 地表面,731.36
# 地表面,731.96
# 地表面,731.73
# 地表面,729.74
# 地表面,726.63
# 地表面,722.86
# 地表面,719.36
# 地表面,716.17
# 地表面,713.26
# 地表面,709.78
# 地表面,706.41
# 地表面,703.65
# 地表面,701.20
# 地表面,698.57
# 地表面,696.29
# 地表面,698.17
# 地表面,701.73
# 地表面,704.77
# 地表面,705.96
# 地表面,704.01
# 地表面,699.84
# 地表面,696.21
# 地表面,694.13
# 地表面,693.43
# 地表面,695.82
# 地表面,699.34
# 地表面,703.31
# 地表面,707.27
# 地表面,711.50
# 地表面,715.28
# 地表面,719.26
# 地表面,722.42
# 地表面,722.22
# 地表面,718.46
# 地表面,713.12
# 地表面,707.27
# 地表面,701.98
# 地表面,698.47
# 地表面,695.05
# 地表面,691.12
# 地表面,687.47
# 地表面,684.31
# 地表面,681.12
# 地表面,677.21
# 地表面,664.15
# 地表面,652.57
# 地表面,649.63
# 地表面,647.54
# 地表面,646.65
# 地表面,644.46
# 地表面,642.13
# 地表面,639.88
# 地表面,638.89
# 地表面,638.66
# 地表面,638.16
# 地表面,636.92
# 地表面,635.87
# 地表面,635.15
# 地表面,633.23
# 地表面,633.29
# 地表面,632.96
# 地表面,632.80
# 地表面,631.63
# 地表面,630.88
# 地表面,630.71
# 地表面,631.60
# 地表面,631.56
# 地表面,817.04
# 地表面,817.98
# 地表面,818.96
# 地表面,819.77
# 地表面,819.79
# 地表面,818.38
# 地表面,815.86
# 地表面,813.24
# 地表面,810.79
# 地表面,808.56
# 地表面,806.42
# 地表面,803.74
# 地表面,800.47
# 地表面,796.87
# 地表面,793.66
# 地表面,790.83
# 地表面,788.51
# 地表面,786.39
# 地表面,783.81
# 地表面,780.58
# 地表面,776.71
# 地表面,772.70
# 地表面,769.00
# 地表面,765.53
# 地表面,761.66
# 地表面,757.20
# 地表面,752.61
# 地表面,748.09
# 地表面,743.92
# 地表面,741.77
# 地表面,743.01
# 地表面,746.63
# 地表面,750.14
# 地表面,753.07
# 地表面,757.20
# 地表面,762.28
# 地表面,766.70
# 地表面,769.67
# 地表面,771.04
# 地表面,769.86
# 地表面,766.95
# 地表面,763.68
# 地表面,760.34
# 地表面,756.82
# 地表面,753.46
# 地表面,750.33
# 地表面,747.22
# 地表面,744.21
# 地表面,741.70
# 地表面,738.74
# 地表面,737.09
# 地表面,738.76
# 地表面,741.17
# 地表面,742.74
# 地表面,744.38
# 地表面,746.74
# 地表面,748.84
# 地表面,750.89
# 地表面,752.95
# 地表面,755.05
# 地表面,757.38
# 地表面,759.93
# 地表面,762.23
# 地表面,764.31
# 地表面,766.54
# 地表面,768.33
# 地表面,769.02
# 地表面,768.60
# 地表面,767.74
# 地表面,766.76
# 地表面,766.07
# 地表面,765.85
# 地表面,765.92
# 地表面,766.66
# 地表面,767.75
# 地表面,769.25
# 地表面,771.06
# 地表面,772.95
# 地表面,775.35
# 地表面,777.58
# 地表面,779.96
# 地表面,782.52
# 地表面,785.10
# 地表面,786.92
# 地表面,785.70
# 地表面,781.13
# 地表面,776.45
# 地表面,772.24
# 地表面,767.76
# 地表面,763.52
# 地表面,759.53
# 地表面,755.38
# 地表面,751.32
# 地表面,747.85
# 地表面,744.61
# 地表面,741.28
# 地表面,737.92
# 地表面,734.44
# 地表面,731.37
# 地表面,728.87
# 地表面,726.51
# 地表面,725.14
# 地表面,724.09
# 地表面,722.73
# 地表面,720.79
# 地表面,719.28
# 地表面,718.59
# 地表面,718.07
# 地表面,717.14
# 地表面,715.87
# 地表面,714.75
# 地表面,713.31
# 地表面,711.98
# 地表面,711.20
# 地表面,710.44
# 地表面,709.83
# 地表面,710.10
# 地表面,712.39
# 地表面,715.65
# 地表面,718.52
# 地表面,721.71
# 地表面,723.86
# 地表面,724.68
# 地表面,723.83
# 地表面,721.58
# 地表面,719.72
# 地表面,718.44
# 地表面,717.20
# 地表面,714.97
# 地表面,713.13
# 地表面,714.39
# 地表面,718.10
# 地表面,721.90
# 地表面,724.98
# 地表面,727.67
# 地表面,729.59
# 地表面,730.54
# 地表面,730.52
# 地表面,729.19
# 地表面,726.71
# 地表面,723.88
# 地表面,720.79
# 地表面,717.69
# 地表面,715.41
# 地表面,714.80
# 地表面,715.35
# 地表面,715.27
# 地表面,714.00
# 地表面,714.52
# 地表面,716.70
# 地表面,718.92
# 地表面,721.55
# 地表面,724.28
# 地表面,726.99
# 地表面,729.53
# 地表面,731.61
# 地表面,732.92
# 地表面,733.62
# 地表面,734.19
# 地表面,734.51
# 地表面,733.70
# 地表面,731.30
# 地表面,727.72
# 地表面,724.18
# 地表面,720.98
# 地表面,717.89
# 地表面,715.04
# 地表面,712.67
# 地表面,709.43
# 地表面,706.94
# 地表面,705.03
# 地表面,701.32
# 地表面,698.22
# 地表面,699.74
# 地表面,703.50
# 地表面,707.06
# 地表面,707.92
# 地表面,705.89
# 地表面,701.92
# 地表面,698.38
# 地表面,696.42
# 地表面,696.02
# 地表面,698.56
# 地表面,702.01
# 地表面,705.53
# 地表面,709.31
# 地表面,712.71
# 地表面,716.81
# 地表面,721.21
# 地表面,724.66
# 地表面,722.94
# 地表面,718.13
# 地表面,712.71
# 地表面,707.15
# 地表面,702.93
# 地表面,698.82
# 地表面,694.45
# 地表面,690.23
# 地表面,685.75
# 地表面,682.12
# 地表面,679.08
# 地表面,672.96
# 地表面,658.23
# 地表面,654.03
# 地表面,651.38
# 地表面,649.63
# 地表面,648.80
# 地表面,647.32
# 地表面,645.88
# 地表面,643.64
# 地表面,643.52
# 地表面,644.79
# 地表面,645.10
# 地表面,644.13
# 地表面,642.44
# 地表面,639.54
# 地表面,636.22
# 地表面,633.58
# 地表面,633.72
# 地表面,634.33
# 地表面,634.22
# 地表面,633.78
# 地表面,632.38
# 地表面,632.43
# 地表面,633.49
# 地表面,818.74
# 地表面,819.32
# 地表面,820.04
# 地表面,820.88
# 地表面,820.90
# 地表面,819.39
# 地表面,816.69
# 地表面,813.51
# 地表面,810.46
# 地表面,808.46
# 地表面,806.43
# 地表面,803.57
# 地表面,800.78
# 地表面,798.05
# 地表面,795.64
# 地表面,793.41
# 地表面,790.83
# 地表面,787.57
# 地表面,783.59
# 地表面,779.31
# 地表面,774.94
# 地表面,770.20
# 地表面,765.39
# 地表面,761.47
# 地表面,758.40
# 地表面,754.59
# 地表面,750.10
# 地表面,746.00
# 地表面,744.23
# 地表面,744.84
# 地表面,747.59
# 地表面,750.43
# 地表面,753.65
# 地表面,757.23
# 地表面,761.20
# 地表面,765.56
# 地表面,769.76
# 地表面,772.78
# 地表面,773.11
# 地表面,770.50
# 地表面,767.22
# 地表面,763.66
# 地表面,760.12
# 地表面,756.83
# 地表面,753.63
# 地表面,750.56
# 地表面,747.54
# 地表面,744.69
# 地表面,742.19
# 地表面,739.37
# 地表面,739.85
# 地表面,742.47
# 地表面,743.78
# 地表面,744.86
# 地表面,747.20
# 地表面,749.11
# 地表面,750.86
# 地表面,752.91
# 地表面,754.94
# 地表面,756.91
# 地表面,759.12
# 地表面,761.38
# 地表面,763.67
# 地表面,766.01
# 地表面,768.27
# 地表面,770.77
# 地表面,771.98
# 地表面,772.07
# 地表面,771.54
# 地表面,770.80
# 地表面,769.83
# 地表面,769.09
# 地表面,769.08
# 地表面,769.46
# 地表面,770.09
# 地表面,771.25
# 地表面,772.58
# 地表面,774.16
# 地表面,776.35
# 地表面,778.40
# 地表面,780.79
# 地表面,783.35
# 地表面,786.09
# 地表面,787.89
# 地表面,787.62
# 地表面,783.72
# 地表面,779.46
# 地表面,775.30
# 地表面,770.60
# 地表面,765.94
# 地表面,761.17
# 地表面,756.60
# 地表面,752.74
# 地表面,749.06
# 地表面,745.74
# 地表面,742.56
# 地表面,739.23
# 地表面,736.02
# 地表面,733.38
# 地表面,730.75
# 地表面,727.86
# 地表面,724.87
# 地表面,723.02
# 地表面,721.99
# 地表面,721.26
# 地表面,720.66
# 地表面,718.86
# 地表面,717.87
# 地表面,716.65
# 地表面,715.47
# 地表面,714.40
# 地表面,713.50
# 地表面,712.56
# 地表面,711.80
# 地表面,712.04
# 地表面,712.75
# 地表面,714.03
# 地表面,717.41
# 地表面,720.70
# 地表面,723.49
# 地表面,726.38
# 地表面,728.30
# 地表面,727.79
# 地表面,725.31
# 地表面,722.92
# 地表面,721.33
# 地表面,720.09
# 地表面,718.50
# 地表面,715.67
# 地表面,714.19
# 地表面,716.35
# 地表面,720.06
# 地表面,724.04
# 地表面,727.73
# 地表面,730.72
# 地表面,732.50
# 地表面,733.33
# 地表面,733.22
# 地表面,731.75
# 地表面,729.21
# 地表面,726.17
# 地表面,723.03
# 地表面,719.72
# 地表面,717.28
# 地表面,716.74
# 地表面,717.23
# 地表面,716.91
# 地表面,716.08
# 地表面,716.96
# 地表面,718.64
# 地表面,720.40
# 地表面,722.93
# 地表面,725.98
# 地表面,728.99
# 地表面,731.69
# 地表面,734.07
# 地表面,735.47
# 地表面,736.40
# 地表面,736.94
# 地表面,736.98
# 地表面,735.91
# 地表面,733.21
# 地表面,729.79
# 地表面,726.28
# 地表面,722.99
# 地表面,720.39
# 地表面,717.64
# 地表面,715.44
# 地表面,713.40
# 地表面,711.53
# 地表面,708.89
# 地表面,704.27
# 地表面,700.46
# 地表面,701.61
# 地表面,705.40
# 地表面,709.25
# 地表面,710.46
# 地表面,708.28
# 地表面,704.63
# 地表面,700.96
# 地表面,698.75
# 地表面,697.23
# 地表面,699.85
# 地表面,703.38
# 地表面,707.03
# 地表面,710.68
# 地表面,714.38
# 地表面,718.22
# 地表面,722.22
# 地表面,725.23
# 地表面,723.64
# 地表面,719.30
# 地表面,714.43
# 地表面,709.95
# 地表面,705.87
# 地表面,702.01
# 地表面,697.45
# 地表面,692.69
# 地表面,687.92
# 地表面,682.63
# 地表面,681.00
# 地表面,672.28
# 地表面,660.89
# 地表面,656.35
# 地表面,655.28
# 地表面,653.31
# 地表面,652.02
# 地表面,650.39
# 地表面,648.70
# 地表面,647.92
# 地表面,648.92
# 地表面,650.07
# 地表面,650.07
# 地表面,648.72
# 地表面,647.00
# 地表面,645.57
# 地表面,641.59
# 地表面,637.71
# 地表面,634.73
# 地表面,634.51
# 地表面,635.35
# 地表面,635.77
# 地表面,635.91
# 地表面,635.62
# 地表面,636.56
# 地表面,820.82
# 地表面,821.21
# 地表面,821.77
# 地表面,822.03
# 地表面,820.75
# 地表面,817.77
# 地表面,814.07
# 地表面,810.04
# 地表面,806.14
# 地表面,802.57
# 地表面,799.86
# 地表面,797.55
# 地表面,795.18
# 地表面,793.28
# 地表面,791.58
# 地表面,789.80
# 地表面,787.73
# 地表面,785.22
# 地表面,781.97
# 地表面,777.94
# 地表面,773.65
# 地表面,768.98
# 地表面,763.82
# 地表面,758.68
# 地表面,754.46
# 地表面,751.19
# 地表面,748.06
# 地表面,747.17
# 地表面,748.28
# 地表面,749.76
# 地表面,752.54
# 地表面,755.03
# 地表面,757.61
# 地表面,761.26
# 地表面,765.60
# 地表面,769.52
# 地表面,772.72
# 地表面,774.53
# 地表面,774.07
# 地表面,771.39
# 地表面,768.28
# 地表面,764.61
# 地表面,760.96
# 地表面,757.35
# 地表面,754.24
# 地表面,751.24
# 地表面,748.29
# 地表面,745.29
# 地表面,742.81
# 地表面,740.94
# 地表面,742.92
# 地表面,745.62
# 地表面,746.30
# 地表面,747.78
# 地表面,749.45
# 地表面,751.06
# 地表面,752.84
# 地表面,754.82
# 地表面,756.75
# 地表面,758.66
# 地表面,760.66
# 地表面,762.85
# 地表面,765.07
# 地表面,767.55
# 地表面,769.96
# 地表面,772.47
# 地表面,774.30
# 地表面,775.30
# 地表面,775.07
# 地表面,774.55
# 地表面,773.82
# 地表面,773.00
# 地表面,772.52
# 地表面,772.44
# 地表面,773.10
# 地表面,773.83
# 地表面,774.86
# 地表面,776.28
# 地表面,778.03
# 地表面,779.96
# 地表面,782.20
# 地表面,784.81
# 地表面,787.34
# 地表面,789.20
# 地表面,788.71
# 地表面,785.57
# 地表面,781.53
# 地表面,777.38
# 地表面,772.82
# 地表面,768.09
# 地表面,763.39
# 地表面,758.98
# 地表面,755.35
# 地表面,752.05
# 地表面,748.81
# 地表面,745.74
# 地表面,742.64
# 地表面,740.49
# 地表面,738.67
# 地表面,735.20
# 地表面,731.62
# 地表面,729.01
# 地表面,727.11
# 地表面,726.05
# 地表面,725.33
# 地表面,722.56
# 地表面,719.63
# 地表面,717.98
# 地表面,716.38
# 地表面,715.10
# 地表面,713.99
# 地表面,713.52
# 地表面,713.85
# 地表面,715.26
# 地表面,717.41
# 地表面,718.34
# 地表面,719.39
# 地表面,722.49
# 地表面,725.87
# 地表面,728.46
# 地表面,730.71
# 地表面,731.23
# 地表面,728.94
# 地表面,726.30
# 地表面,724.26
# 地表面,722.79
# 地表面,721.30
# 地表面,719.23
# 地表面,716.80
# 地表面,715.71
# 地表面,717.79
# 地表面,721.37
# 地表面,725.42
# 地表面,729.59
# 地表面,733.02
# 地表面,735.14
# 地表面,736.06
# 地表面,735.62
# 地表面,733.72
# 地表面,731.16
# 地表面,728.09
# 地表面,724.64
# 地表面,721.40
# 地表面,719.06
# 地表面,718.66
# 地表面,719.19
# 地表面,718.41
# 地表面,717.87
# 地表面,718.90
# 地表面,720.31
# 地表面,721.89
# 地表面,724.49
# 地表面,727.78
# 地表面,730.93
# 地表面,733.87
# 地表面,736.37
# 地表面,738.17
# 地表面,739.28
# 地表面,739.68
# 地表面,739.42
# 地表面,738.18
# 地表面,735.42
# 地表面,732.06
# 地表面,728.92
# 地表面,725.73
# 地表面,722.93
# 地表面,720.50
# 地表面,718.52
# 地表面,716.76
# 地表面,715.11
# 地表面,711.70
# 地表面,707.30
# 地表面,703.06
# 地表面,703.19
# 地表面,707.17
# 地表面,711.51
# 地表面,713.13
# 地表面,710.77
# 地表面,707.25
# 地表面,703.54
# 地表面,701.04
# 地表面,699.20
# 地表面,700.88
# 地表面,704.44
# 地表面,708.26
# 地表面,712.12
# 地表面,716.40
# 地表面,720.31
# 地表面,724.00
# 地表面,726.58
# 地表面,724.39
# 地表面,719.88
# 地表面,714.58
# 地表面,710.15
# 地表面,706.32
# 地表面,702.80
# 地表面,698.67
# 地表面,695.03
# 地表面,690.76
# 地表面,683.65
# 地表面,679.92
# 地表面,674.68
# 地表面,671.37
# 地表面,662.76
# 地表面,659.96
# 地表面,657.82
# 地表面,656.19
# 地表面,654.73
# 地表面,653.70
# 地表面,653.72
# 地表面,655.42
# 地表面,655.94
# 地表面,654.24
# 地表面,653.51
# 地表面,651.38
# 地表面,648.06
# 地表面,645.76
# 地表面,642.54
# 地表面,639.25
# 地表面,636.37
# 地表面,635.65
# 地表面,636.27
# 地表面,637.05
# 地表面,637.97
# 地表面,638.90
# 地表面,823.62
# 地表面,823.78
# 地表面,823.89
# 地表面,823.45
# 地表面,821.21
# 地表面,817.48
# 地表面,813.43
# 地表面,808.99
# 地表面,803.90
# 地表面,798.23
# 地表面,793.26
# 地表面,789.94
# 地表面,787.98
# 地表面,786.68
# 地表面,784.99
# 地表面,783.25
# 地表面,781.80
# 地表面,780.24
# 地表面,778.17
# 地表面,775.05
# 地表面,771.35
# 地表面,767.26
# 地表面,762.43
# 地表面,757.06
# 地表面,752.61
# 地表面,750.29
# 地表面,750.44
# 地表面,752.37
# 地表面,754.33
# 地表面,755.28
# 地表面,757.40
# 地表面,759.84
# 地表面,761.90
# 地表面,765.25
# 地表面,769.09
# 地表面,772.99
# 地表面,775.61
# 地表面,776.16
# 地表面,774.78
# 地表面,772.34
# 地表面,769.42
# 地表面,766.01
# 地表面,762.05
# 地表面,758.53
# 地表面,755.39
# 地表面,752.32
# 地表面,749.45
# 地表面,746.63
# 地表面,743.34
# 地表面,741.78
# 地表面,744.78
# 地表面,747.81
# 地表面,749.22
# 地表面,750.38
# 地表面,751.50
# 地表面,752.97
# 地表面,754.67
# 地表面,756.57
# 地表面,758.38
# 地表面,760.17
# 地表面,762.17
# 地表面,764.21
# 地表面,766.54
# 地表面,769.01
# 地表面,771.43
# 地表面,774.20
# 地表面,776.16
# 地表面,777.74
# 地表面,778.67
# 地表面,778.32
# 地表面,777.73
# 地表面,777.16
# 地表面,776.67
# 地表面,776.73
# 地表面,776.80
# 地表面,777.14
# 地表面,777.81
# 地表面,778.89
# 地表面,780.53
# 地表面,781.95
# 地表面,784.15
# 地表面,786.51
# 地表面,788.85
# 地表面,790.11
# 地表面,788.20
# 地表面,784.94
# 地表面,781.10
# 地表面,777.04
# 地表面,773.08
# 地表面,769.66
# 地表面,766.26
# 地表面,762.95
# 地表面,759.67
# 地表面,756.07
# 地表面,752.30
# 地表面,749.29
# 地表面,746.39
# 地表面,744.08
# 地表面,740.72
# 地表面,737.21
# 地表面,734.62
# 地表面,732.67
# 地表面,730.68
# 地表面,727.19
# 地表面,723.58
# 地表面,720.57
# 地表面,718.47
# 地表面,717.01
# 地表面,715.65
# 地表面,715.42
# 地表面,716.48
# 地表面,717.52
# 地表面,717.73
# 地表面,719.95
# 地表面,723.13
# 地表面,724.11
# 地表面,724.88
# 地表面,727.29
# 地表面,730.60
# 地表面,733.14
# 地表面,734.29
# 地表面,732.77
# 地表面,730.04
# 地表面,727.57
# 地表面,725.66
# 地表面,723.78
# 地表面,721.54
# 地表面,719.36
# 地表面,717.59
# 地表面,717.59
# 地表面,720.53
# 地表面,724.19
# 地表面,727.96
# 地表面,731.60
# 地表面,734.57
# 地表面,736.94
# 地表面,738.07
# 地表面,737.37
# 地表面,735.23
# 地表面,732.43
# 地表面,729.22
# 地表面,725.67
# 地表面,722.74
# 地表面,720.98
# 地表面,720.76
# 地表面,720.99
# 地表面,719.82
# 地表面,719.55
# 地表面,720.79
# 地表面,722.00
# 地表面,723.62
# 地表面,726.36
# 地表面,729.63
# 地表面,732.81
# 地表面,735.85
# 地表面,738.62
# 地表面,740.66
# 地表面,741.91
# 地表面,742.54
# 地表面,742.35
# 地表面,740.63
# 地表面,737.66
# 地表面,734.40
# 地表面,731.29
# 地表面,728.26
# 地表面,725.59
# 地表面,723.36
# 地表面,721.24
# 地表面,719.21
# 地表面,717.18
# 地表面,714.55
# 地表面,710.43
# 地表面,705.85
# 地表面,705.11
# 地表面,708.91
# 地表面,713.45
# 地表面,715.51
# 地表面,713.55
# 地表面,710.25
# 地表面,706.73
# 地表面,703.92
# 地表面,701.84
# 地表面,701.78
# 地表面,704.71
# 地表面,708.42
# 地表面,712.83
# 地表面,717.71
# 地表面,722.24
# 地表面,726.54
# 地表面,728.25
# 地表面,725.81
# 地表面,721.48
# 地表面,716.96
# 地表面,713.95
# 地表面,711.14
# 地表面,707.74
# 地表面,703.68
# 地表面,700.18
# 地表面,695.08
# 地表面,684.81
# 地表面,677.96
# 地表面,676.29
# 地表面,674.62
# 地表面,672.23
# 地表面,668.37
# 地表面,666.34
# 地表面,664.24
# 地表面,662.56
# 地表面,662.20
# 地表面,662.92
# 地表面,662.03
# 地表面,660.38
# 地表面,657.45
# 地表面,654.98
# 地表面,654.28
# 地表面,652.23
# 地表面,648.84
# 地表面,646.80
# 地表面,643.63
# 地表面,640.54
# 地表面,638.36
# 地表面,637.62
# 地表面,637.69
# 地表面,638.28
# 地表面,639.71
# 地表面,826.30
# 地表面,826.24
# 地表面,826.00
# 地表面,825.02
# 地表面,822.32
# 地表面,818.34
# 地表面,814.30
# 地表面,810.18
# 地表面,805.34
# 地表面,799.16
# 地表面,792.36
# 地表面,786.91
# 地表面,783.24
# 地表面,780.80
# 地表面,778.90
# 地表面,777.18
# 地表面,775.58
# 地表面,774.05
# 地表面,772.49
# 地表面,770.49
# 地表面,767.59
# 地表面,763.76
# 地表面,759.13
# 地表面,754.77
# 地表面,752.80
# 地表面,754.06
# 地表面,756.60
# 地表面,758.74
# 地表面,760.26
# 地表面,761.07
# 地表面,762.11
# 地表面,764.46
# 地表面,766.77
# 地表面,769.50
# 地表面,772.50
# 地表面,776.11
# 地表面,778.14
# 地表面,777.69
# 地表面,775.79
# 地表面,773.39
# 地表面,770.66
# 地表面,767.76
# 地表面,763.97
# 地表面,760.34
# 地表面,757.08
# 地表面,753.94
# 地表面,751.04
# 地表面,748.50
# 地表面,745.26
# 地表面,743.20
# 地表面,745.06
# 地表面,748.87
# 地表面,750.93
# 地表面,752.23
# 地表面,753.32
# 地表面,754.85
# 地表面,756.66
# 地表面,758.34
# 地表面,760.01
# 地表面,761.75
# 地表面,763.81
# 地表面,766.01
# 地表面,768.10
# 地表面,770.31
# 地表面,772.75
# 地表面,775.41
# 地表面,777.68
# 地表面,779.70
# 地表面,781.25
# 地表面,781.74
# 地表面,781.45
# 地表面,781.23
# 地表面,780.99
# 地表面,780.94
# 地表面,780.89
# 地表面,780.88
# 地表面,781.33
# 地表面,782.13
# 地表面,783.17
# 地表面,784.55
# 地表面,786.42
# 地表面,788.20
# 地表面,789.87
# 地表面,789.98
# 地表面,786.76
# 地表面,783.48
# 地表面,779.76
# 地表面,775.33
# 地表面,771.50
# 地表面,768.15
# 地表面,764.88
# 地表面,761.43
# 地表面,757.65
# 地表面,753.63
# 地表面,750.18
# 地表面,747.15
# 地表面,743.70
# 地表面,741.32
# 地表面,739.18
# 地表面,736.79
# 地表面,734.15
# 地表面,731.54
# 地表面,728.76
# 地表面,725.09
# 地表面,721.75
# 地表面,719.59
# 地表面,718.08
# 地表面,717.46
# 地表面,718.71
# 地表面,719.91
# 地表面,722.34
# 地表面,724.03
# 地表面,722.68
# 地表面,723.14
# 地表面,727.27
# 地表面,729.76
# 地表面,730.77
# 地表面,732.24
# 地表面,735.00
# 地表面,736.96
# 地表面,736.80
# 地表面,734.45
# 地表面,731.26
# 地表面,728.73
# 地表面,726.47
# 地表面,724.20
# 地表面,721.79
# 地表面,719.38
# 地表面,718.91
# 地表面,721.57
# 地表面,725.22
# 地表面,728.30
# 地表面,731.21
# 地表面,733.81
# 地表面,736.25
# 地表面,738.47
# 地表面,739.37
# 地表面,738.46
# 地表面,736.27
# 地表面,733.39
# 地表面,730.14
# 地表面,726.68
# 地表面,723.98
# 地表面,722.66
# 地表面,722.94
# 地表面,722.92
# 地表面,721.90
# 地表面,721.82
# 地表面,722.61
# 地表面,723.91
# 地表面,725.77
# 地表面,728.38
# 地表面,731.61
# 地表面,734.80
# 地表面,737.89
# 地表面,740.70
# 地表面,743.00
# 地表面,744.53
# 地表面,745.13
# 地表面,744.55
# 地表面,742.53
# 地表面,739.53
# 地表面,736.58
# 地表面,733.27
# 地表面,730.72
# 地表面,728.10
# 地表面,725.49
# 地表面,723.18
# 地表面,720.82
# 地表面,719.13
# 地表面,717.18
# 地表面,713.38
# 地表面,708.80
# 地表面,707.57
# 地表面,711.12
# 地表面,715.82
# 地表面,718.00
# 地表面,716.73
# 地表面,713.43
# 地表面,709.72
# 地表面,707.13
# 地表面,704.82
# 地表面,703.86
# 地表面,706.25
# 地表面,710.33
# 地表面,714.20
# 地表面,718.92
# 地表面,723.90
# 地表面,728.56
# 地表面,730.42
# 地表面,728.63
# 地表面,725.29
# 地表面,722.38
# 地表面,719.48
# 地表面,716.47
# 地表面,712.72
# 地表面,708.62
# 地表面,704.28
# 地表面,698.85
# 地表面,689.17
# 地表面,679.83
# 地表面,679.48
# 地表面,678.77
# 地表面,677.40
# 地表面,674.81
# 地表面,672.88
# 地表面,671.94
# 地表面,671.88
# 地表面,670.91
# 地表面,670.03
# 地表面,667.22
# 地表面,662.54
# 地表面,661.02
# 地表面,658.20
# 地表面,655.27
# 地表面,654.37
# 地表面,653.00
# 地表面,650.63
# 地表面,648.05
# 地表面,645.06
# 地表面,644.06
# 地表面,643.82
# 地表面,643.88
# 地表面,643.62
# 地表面,643.31
# 地表面,829.11
# 地表面,828.88
# 地表面,828.23
# 地表面,826.46
# 地表面,823.16
# 地表面,819.03
# 地表面,815.07
# 地表面,811.09
# 地表面,806.58
# 地表面,801.29
# 地表面,794.54
# 地表面,788.02
# 地表面,782.90
# 地表面,778.50
# 地表面,775.12
# 地表面,772.16
# 地表面,769.80
# 地表面,767.88
# 地表面,766.16
# 地表面,764.45
# 地表面,762.22
# 地表面,758.98
# 地表面,756.14
# 地表面,755.41
# 地表面,756.81
# 地表面,759.52
# 地表面,762.50
# 地表面,764.72
# 地表面,766.09
# 地表面,766.95
# 地表面,767.70
# 地表面,769.18
# 地表面,771.15
# 地表面,773.58
# 地表面,776.40
# 地表面,779.41
# 地表面,780.33
# 地表面,779.28
# 地表面,777.34
# 地表面,774.87
# 地表面,772.15
# 地表面,769.23
# 地表面,765.89
# 地表面,762.06
# 地表面,758.89
# 地表面,755.83
# 地表面,752.86
# 地表面,750.21
# 地表面,747.79
# 地表面,745.09
# 地表面,745.03
# 地表面,748.62
# 地表面,752.06
# 地表面,753.79
# 地表面,754.92
# 地表面,756.41
# 地表面,758.15
# 地表面,759.93
# 地表面,761.62
# 地表面,763.41
# 地表面,765.43
# 地表面,767.56
# 地表面,769.59
# 地表面,771.69
# 地表面,774.06
# 地表面,776.60
# 地表面,778.74
# 地表面,781.05
# 地表面,783.14
# 地表面,784.49
# 地表面,785.12
# 地表面,785.05
# 地表面,784.99
# 地表面,784.88
# 地表面,784.83
# 地表面,784.87
# 地表面,785.09
# 地表面,785.63
# 地表面,786.36
# 地表面,787.50
# 地表面,788.88
# 地表面,790.33
# 地表面,790.62
# 地表面,788.63
# 地表面,784.97
# 地表面,781.47
# 地表面,777.84
# 地表面,773.98
# 地表面,770.24
# 地表面,767.03
# 地表面,763.53
# 地表面,759.81
# 地表面,755.77
# 地表面,751.70
# 地表面,747.69
# 地表面,743.78
# 地表面,740.23
# 地表面,738.23
# 地表面,736.69
# 地表面,733.82
# 地表面,730.72
# 地表面,728.12
# 地表面,726.19
# 地表面,723.76
# 地表面,721.44
# 地表面,719.96
# 地表面,719.49
# 地表面,721.23
# 地表面,722.75
# 地表面,724.05
# 地表面,726.86
# 地表面,729.08
# 地表面,728.25
# 地表面,727.38
# 地表面,729.98
# 地表面,733.72
# 地表面,736.15
# 地表面,737.98
# 地表面,739.69
# 地表面,740.09
# 地表面,738.18
# 地表面,735.15
# 地表面,731.86
# 地表面,729.17
# 地表面,727.00
# 地表面,724.68
# 地表面,722.58
# 地表面,721.26
# 地表面,722.27
# 地表面,725.43
# 地表面,728.65
# 地表面,731.37
# 地表面,733.71
# 地表面,736.04
# 地表面,738.19
# 地表面,739.91
# 地表面,740.61
# 地表面,739.43
# 地表面,736.96
# 地表面,733.98
# 地表面,730.58
# 地表面,727.46
# 地表面,725.31
# 地表面,724.63
# 地表面,724.99
# 地表面,724.72
# 地表面,723.98
# 地表面,724.09
# 地表面,724.49
# 地表面,725.55
# 地表面,727.75
# 地表面,730.28
# 地表面,733.00
# 地表面,736.39
# 地表面,739.74
# 地表面,742.68
# 地表面,745.11
# 地表面,746.74
# 地表面,746.87
# 地表面,745.61
# 地表面,743.21
# 地表面,740.37
# 地表面,737.31
# 地表面,734.35
# 地表面,731.94
# 地表面,729.44
# 地表面,727.46
# 地表面,725.51
# 地表面,723.69
# 地表面,721.88
# 地表面,719.43
# 地表面,715.08
# 地表面,710.47
# 地表面,710.35
# 地表面,714.25
# 地表面,718.44
# 地表面,721.12
# 地表面,719.42
# 地表面,716.29
# 地表面,713.01
# 地表面,709.59
# 地表面,708.02
# 地表面,705.98
# 地表面,707.93
# 地表面,712.44
# 地表面,716.63
# 地表面,721.14
# 地表面,725.85
# 地表面,730.45
# 地表面,733.02
# 地表面,732.22
# 地表面,730.05
# 地表面,727.52
# 地表面,724.97
# 地表面,721.12
# 地表面,716.88
# 地表面,712.64
# 地表面,707.44
# 地表面,701.95
# 地表面,693.38
# 地表面,685.71
# 地表面,683.53
# 地表面,682.87
# 地表面,681.54
# 地表面,679.89
# 地表面,679.46
# 地表面,677.68
# 地表面,677.09
# 地表面,676.31
# 地表面,674.13
# 地表面,671.68
# 地表面,667.30
# 地表面,662.39
# 地表面,661.28
# 地表面,658.62
# 地表面,655.35
# 地表面,654.89
# 地表面,654.45
# 地表面,652.33
# 地表面,650.27
# 地表面,649.73
# 地表面,649.63
# 地表面,649.65
# 地表面,649.63
# 地表面,648.86
# 地表面,832.03
# 地表面,831.40
# 地表面,830.16
# 地表面,827.82
# 地表面,824.14
# 地表面,820.19
# 地表面,816.17
# 地表面,812.00
# 地表面,807.59
# 地表面,802.53
# 地表面,797.14
# 地表面,791.86
# 地表面,787.11
# 地表面,782.56
# 地表面,778.05
# 地表面,773.45
# 地表面,769.77
# 地表面,767.16
# 地表面,764.27
# 地表面,761.58
# 地表面,759.20
# 地表面,758.10
# 地表面,758.30
# 地表面,759.52
# 地表面,761.92
# 地表面,764.85
# 地表面,767.68
# 地表面,769.76
# 地表面,771.46
# 地表面,772.19
# 地表面,773.03
# 地表面,774.09
# 地表面,775.56
# 地表面,777.67
# 地表面,780.79
# 地表面,782.74
# 地表面,782.44
# 地表面,781.01
# 地表面,779.24
# 地表面,777.05
# 地表面,774.63
# 地表面,771.48
# 地表面,767.77
# 地表面,763.93
# 地表面,760.79
# 地表面,757.99
# 地表面,754.81
# 地表面,751.73
# 地表面,749.50
# 地表面,747.35
# 地表面,745.73
# 地表面,746.65
# 地表面,749.77
# 地表面,753.28
# 地表面,755.99
# 地表面,757.67
# 地表面,759.43
# 地表面,761.16
# 地表面,762.87
# 地表面,764.67
# 地表面,766.66
# 地表面,768.60
# 地表面,770.77
# 地表面,772.89
# 地表面,775.26
# 地表面,777.37
# 地表面,779.72
# 地表面,782.04
# 地表面,784.44
# 地表面,786.55
# 地表面,787.76
# 地表面,788.76
# 地表面,789.02
# 地表面,789.07
# 地表面,789.14
# 地表面,788.98
# 地表面,788.99
# 地表面,789.41
# 地表面,789.93
# 地表面,790.69
# 地表面,791.63
# 地表面,792.16
# 地表面,790.92
# 地表面,787.16
# 地表面,783.61
# 地表面,780.20
# 地表面,776.61
# 地表面,773.13
# 地表面,769.61
# 地表面,766.26
# 地表面,762.41
# 地表面,758.59
# 地表面,754.66
# 地表面,750.77
# 地表面,746.60
# 地表面,742.81
# 地表面,739.39
# 地表面,737.10
# 地表面,735.14
# 地表面,732.73
# 地表面,730.82
# 地表面,728.66
# 地表面,726.69
# 地表面,723.73
# 地表面,721.25
# 地表面,720.68
# 地表面,722.08
# 地表面,725.04
# 地表面,726.60
# 地表面,728.11
# 地表面,731.07
# 地表面,733.62
# 地表面,733.32
# 地表面,732.06
# 地表面,733.12
# 地表面,736.88
# 地表面,740.47
# 地表面,742.69
# 地表面,743.14
# 地表面,741.22
# 地表面,738.09
# 地表面,734.76
# 地表面,731.92
# 地表面,729.92
# 地表面,727.97
# 地表面,725.33
# 地表面,724.48
# 地表面,725.58
# 地表面,727.08
# 地表面,729.44
# 地表面,731.91
# 地表面,734.16
# 地表面,736.28
# 地表面,738.35
# 地表面,740.20
# 地表面,741.51
# 地表面,741.56
# 地表面,740.06
# 地表面,737.56
# 地表面,734.45
# 地表面,731.30
# 地表面,728.64
# 地表面,726.82
# 地表面,726.58
# 地表面,726.70
# 地表面,726.24
# 地表面,725.92
# 地表面,726.23
# 地表面,726.65
# 地表面,727.73
# 地表面,729.73
# 地表面,731.93
# 地表面,734.68
# 地表面,738.21
# 地表面,741.53
# 地表面,744.41
# 地表面,746.79
# 地表面,748.13
# 地表面,747.71
# 地表面,745.90
# 地表面,743.36
# 地表面,740.60
# 地表面,737.65
# 地表面,735.04
# 地表面,732.97
# 地表面,730.86
# 地表面,729.11
# 地表面,727.84
# 地表面,726.40
# 地表面,724.38
# 地表面,721.28
# 地表面,717.06
# 地表面,712.54
# 地表面,713.32
# 地表面,717.36
# 地表面,721.57
# 地表面,724.19
# 地表面,722.45
# 地表面,719.25
# 地表面,715.78
# 地表面,712.74
# 地表面,710.17
# 地表面,708.08
# 地表面,709.78
# 地表面,714.22
# 地表面,718.08
# 地表面,722.59
# 地表面,727.51
# 地表面,731.77
# 地表面,735.26
# 地表面,736.90
# 地表面,735.27
# 地表面,732.42
# 地表面,728.78
# 地表面,724.19
# 地表面,719.57
# 地表面,714.68
# 地表面,709.44
# 地表面,704.45
# 地表面,696.35
# 地表面,689.78
# 地表面,688.34
# 地表面,687.09
# 地表面,685.79
# 地表面,684.53
# 地表面,684.68
# 地表面,684.10
# 地表面,681.45
# 地表面,679.38
# 地表面,677.39
# 地表面,674.32
# 地表面,671.92
# 地表面,667.28
# 地表面,662.78
# 地表面,661.28
# 地表面,658.91
# 地表面,656.09
# 地表面,655.34
# 地表面,654.64
# 地表面,653.80
# 地表面,653.80
# 地表面,653.52
# 地表面,653.43
# 地表面,653.32
# 地表面,652.91
# 地表面,834.86
# 地表面,833.50
# 地表面,831.33
# 地表面,828.41
# 地表面,824.78
# 地表面,820.89
# 地表面,816.73
# 地表面,812.34
# 地表面,807.86
# 地表面,803.13
# 地表面,798.40
# 地表面,793.49
# 地表面,788.78
# 地表面,784.28
# 地表面,779.91
# 地表面,777.04
# 地表面,775.55
# 地表面,773.11
# 地表面,769.73
# 地表面,765.97
# 地表面,762.34
# 地表面,761.35
# 地表面,762.68
# 地表面,764.20
# 地表面,765.98
# 地表面,768.92
# 地表面,772.10
# 地表面,774.87
# 地表面,776.83
# 地表面,777.51
# 地表面,777.92
# 地表面,778.80
# 地表面,780.22
# 地表面,782.14
# 地表面,784.58
# 地表面,785.63
# 地表面,785.01
# 地表面,783.68
# 地表面,781.64
# 地表面,779.19
# 地表面,776.35
# 地表面,773.31
# 地表面,769.72
# 地表面,765.98
# 地表面,762.79
# 地表面,760.06
# 地表面,756.86
# 地表面,753.09
# 地表面,750.84
# 地表面,749.91
# 地表面,748.76
# 地表面,747.77
# 地表面,748.17
# 地表面,751.13
# 地表面,755.59
# 地表面,758.28
# 地表面,759.84
# 地表面,761.60
# 地表面,763.66
# 地表面,765.62
# 地表面,767.56
# 地表面,769.58
# 地表面,771.77
# 地表面,773.81
# 地表面,775.99
# 地表面,778.28
# 地表面,780.34
# 地表面,782.73
# 地表面,785.23
# 地表面,787.55
# 地表面,789.67
# 地表面,791.35
# 地表面,792.50
# 地表面,793.04
# 地表面,793.25
# 地表面,793.63
# 地表面,793.23
# 地表面,793.14
# 地表面,793.62
# 地表面,794.11
# 地表面,794.55
# 地表面,794.14
# 地表面,791.13
# 地表面,787.14
# 地表面,783.60
# 地表面,780.00
# 地表面,776.61
# 地表面,772.77
# 地表面,769.70
# 地表面,766.22
# 地表面,762.34
# 地表面,758.79
# 地表面,755.08
# 地表面,750.94
# 地表面,746.89
# 地表面,743.93
# 地表面,741.40
# 地表面,739.17
# 地表面,737.76
# 地表面,736.11
# 地表面,734.37
# 地表面,732.16
# 地表面,729.62
# 地表面,725.83
# 地表面,722.54
# 地表面,722.36
# 地表面,725.09
# 地表面,727.90
# 地表面,730.07
# 地表面,732.04
# 地表面,734.14
# 地表面,737.19
# 地表面,738.40
# 地表面,737.16
# 地表面,737.42
# 地表面,740.51
# 地表面,743.78
# 地表面,745.34
# 地表面,743.89
# 地表面,740.53
# 地表面,737.23
# 地表面,734.56
# 地表面,732.69
# 地表面,731.04
# 地表面,728.54
# 地表面,726.24
# 地表面,727.31
# 地表面,729.93
# 地表面,731.10
# 地表面,732.74
# 地表面,734.77
# 地表面,736.85
# 地表面,738.90
# 地表面,740.91
# 地表面,742.47
# 地表面,743.22
# 地表面,742.67
# 地表面,740.81
# 地表面,738.20
# 地表面,735.20
# 地表面,732.30
# 地表面,729.96
# 地表面,728.55
# 地表面,728.76
# 地表面,728.83
# 地表面,727.94
# 地表面,727.84
# 地表面,728.57
# 地表面,729.19
# 地表面,730.20
# 地表面,731.71
# 地表面,733.52
# 地表面,736.67
# 地表面,740.26
# 地表面,743.31
# 地表面,746.02
# 地表面,748.22
# 地表面,748.94
# 地表面,747.72
# 地表面,745.70
# 地表面,743.26
# 地表面,740.61
# 地表面,738.23
# 地表面,735.91
# 地表面,734.06
# 地表面,732.49
# 地表面,731.15
# 地表面,729.79
# 地表面,728.48
# 地表面,726.72
# 地表面,723.63
# 地表面,719.33
# 地表面,715.07
# 地表面,715.68
# 地表面,720.17
# 地表面,724.37
# 地表面,726.86
# 地表面,725.64
# 地表面,722.78
# 地表面,719.40
# 地表面,716.20
# 地表面,713.04
# 地表面,710.85
# 地表面,712.20
# 地表面,716.64
# 地表面,720.45
# 地表面,724.90
# 地表面,729.65
# 地表面,733.94
# 地表面,737.78
# 地表面,740.38
# 地表面,738.59
# 地表面,734.58
# 地表面,729.76
# 地表面,724.95
# 地表面,720.18
# 地表面,715.57
# 地表面,710.74
# 地表面,705.87
# 地表面,700.55
# 地表面,695.28
# 地表面,692.68
# 地表面,691.52
# 地表面,690.96
# 地表面,691.21
# 地表面,691.19
# 地表面,688.80
# 地表面,685.91
# 地表面,683.49
# 地表面,680.44
# 地表面,677.71
# 地表面,674.30
# 地表面,671.94
# 地表面,667.09
# 地表面,662.74
# 地表面,661.30
# 地表面,659.49
# 地表面,656.62
# 地表面,655.27
# 地表面,654.86
# 地表面,654.62
# 地表面,654.18
# 地表面,653.89
# 地表面,653.82
# 地表面,653.70
# 地表面,836.76
# 地表面,834.48
# 地表面,831.19
# 地表面,827.41
# 地表面,823.63
# 地表面,819.96
# 地表面,816.12
# 地表面,811.96
# 地表面,807.53
# 地表面,803.12
# 地表面,798.81
# 地表面,794.50
# 地表面,790.35
# 地表面,786.88
# 地表面,784.54
# 地表面,783.27
# 地表面,781.61
# 地表面,778.05
# 地表面,772.93
# 地表面,767.57
# 地表面,764.54
# 地表面,764.79
# 地表面,766.96
# 地表面,769.19
# 地表面,770.87
# 地表面,773.58
# 地表面,776.82
# 地表面,779.69
# 地表面,781.81
# 地表面,782.78
# 地表面,783.20
# 地表面,784.08
# 地表面,785.40
# 地表面,786.97
# 地表面,788.29
# 地表面,788.45
# 地表面,787.52
# 地表面,786.08
# 地表面,784.16
# 地表面,781.73
# 地表面,778.85
# 地表面,775.71
# 地表面,772.09
# 地表面,768.40
# 地表面,765.08
# 地表面,762.03
# 地表面,758.28
# 地表面,754.51
# 地表面,752.37
# 地表面,751.46
# 地表面,751.05
# 地表面,749.97
# 地表面,749.41
# 地表面,751.84
# 地表面,755.66
# 地表面,758.41
# 地表面,760.09
# 地表面,761.96
# 地表面,764.05
# 地表面,766.20
# 地表面,768.38
# 地表面,770.56
# 地表面,772.71
# 地表面,774.77
# 地表面,776.81
# 地表面,778.95
# 地表面,781.17
# 地表面,783.49
# 地表面,785.78
# 地表面,788.06
# 地表面,790.24
# 地表面,792.75
# 地表面,794.67
# 地表面,796.06
# 地表面,796.84
# 地表面,797.23
# 地表面,797.30
# 地表面,797.30
# 地表面,797.42
# 地表面,797.68
# 地表面,797.43
# 地表面,795.31
# 地表面,791.53
# 地表面,787.73
# 地表面,784.15
# 地表面,780.85
# 地表面,777.51
# 地表面,773.94
# 地表面,770.61
# 地表面,767.36
# 地表面,764.07
# 地表面,760.78
# 地表面,757.35
# 地表面,754.44
# 地表面,750.90
# 地表面,747.94
# 地表面,745.65
# 地表面,744.44
# 地表面,742.68
# 地表面,740.28
# 地表面,737.40
# 地表面,734.45
# 地表面,731.11
# 地表面,727.31
# 地表面,723.84
# 地表面,723.84
# 地表面,727.63
# 地表面,731.26
# 地表面,734.20
# 地表面,736.68
# 地表面,738.70
# 地表面,741.25
# 地表面,742.77
# 地表面,742.31
# 地表面,742.87
# 地表面,744.88
# 地表面,746.34
# 地表面,745.70
# 地表面,742.50
# 地表面,739.19
# 地表面,736.82
# 地表面,735.29
# 地表面,733.33
# 地表面,730.75
# 地表面,728.29
# 地表面,727.63
# 地表面,729.93
# 地表面,732.71
# 地表面,734.00
# 地表面,735.60
# 地表面,737.54
# 地表面,739.65
# 地表面,741.70
# 地表面,743.62
# 地表面,744.88
# 地表面,745.07
# 地表面,743.89
# 地表面,741.71
# 地表面,739.14
# 地表面,736.41
# 地表面,733.74
# 地表面,731.61
# 地表面,730.55
# 地表面,730.76
# 地表面,730.77
# 地表面,729.65
# 地表面,729.52
# 地表面,730.66
# 地表面,731.42
# 地表面,732.18
# 地表面,733.61
# 地表面,735.87
# 地表面,738.92
# 地表面,742.13
# 地表面,745.05
# 地表面,747.87
# 地表面,749.71
# 地表面,749.58
# 地表面,748.00
# 地表面,745.95
# 地表面,743.49
# 地表面,741.06
# 地表面,738.82
# 地表面,736.80
# 地表面,735.22
# 地表面,734.42
# 地表面,733.37
# 地表面,732.21
# 地表面,730.53
# 地表面,729.46
# 地表面,726.23
# 地表面,722.08
# 地表面,718.09
# 地表面,717.36
# 地表面,721.64
# 地表面,726.50
# 地表面,729.55
# 地表面,729.19
# 地表面,726.53
# 地表面,723.30
# 地表面,719.83
# 地表面,716.03
# 地表面,713.45
# 地表面,714.23
# 地表面,718.61
# 地表面,723.09
# 地表面,727.47
# 地表面,732.04
# 地表面,736.25
# 地表面,740.02
# 地表面,741.92
# 地表面,738.28
# 地表面,733.61
# 地表面,728.71
# 地表面,723.86
# 地表面,719.69
# 地表面,715.18
# 地表面,711.05
# 地表面,708.06
# 地表面,707.30
# 地表面,703.04
# 地表面,704.68
# 地表面,710.05
# 地表面,701.06
# 地表面,702.30
# 地表面,700.19
# 地表面,695.18
# 地表面,690.37
# 地表面,687.14
# 地表面,684.22
# 地表面,681.09
# 地表面,677.83
# 地表面,674.80
# 地表面,671.65
# 地表面,667.08
# 地表面,662.61
# 地表面,661.38
# 地表面,660.14
# 地表面,659.17
# 地表面,658.83
# 地表面,658.43
# 地表面,658.05
# 地表面,657.73
# 地表面,657.42
# 地表面,656.90
# 地表面,837.46
# 地表面,833.99
# 地表面,830.31
# 地表面,826.79
# 地表面,823.61
# 地表面,820.63
# 地表面,817.31
# 地表面,813.63
# 地表面,809.75
# 地表面,805.67
# 地表面,801.76
# 地表面,798.26
# 地表面,794.98
# 地表面,792.20
# 地表面,789.97
# 地表面,787.10
# 地表面,783.20
# 地表面,778.33
# 地表面,772.45
# 地表面,768.51
# 地表面,767.94
# 地表面,769.85
# 地表面,772.43
# 地表面,774.74
# 地表面,776.44
# 地表面,778.61
# 地表面,781.31
# 地表面,784.01
# 地表面,786.08
# 地表面,787.40
# 地表面,788.28
# 地表面,789.12
# 地表面,790.13
# 地表面,791.05
# 地表面,791.40
# 地表面,790.86
# 地表面,789.74
# 地表面,788.28
# 地表面,786.50
# 地表面,784.27
# 地表面,781.44
# 地表面,778.34
# 地表面,775.10
# 地表面,771.53
# 地表面,767.68
# 地表面,763.95
# 地表面,760.20
# 地表面,756.62
# 地表面,754.02
# 地表面,753.05
# 地表面,752.30
# 地表面,750.98
# 地表面,751.16
# 地表面,752.50
# 地表面,754.76
# 地表面,757.49
# 地表面,759.83
# 地表面,761.97
# 地表面,764.42
# 地表面,766.72
# 地表面,768.95
# 地表面,771.16
# 地表面,773.19
# 地表面,775.16
# 地表面,777.25
# 地表面,779.27
# 地表面,781.18
# 地表面,783.29
# 地表面,785.51
# 地表面,787.97
# 地表面,790.40
# 地表面,793.13
# 地表面,795.65
# 地表面,797.42
# 地表面,799.54
# 地表面,800.64
# 地表面,801.27
# 地表面,801.32
# 地表面,801.49
# 地表面,801.22
# 地表面,799.95
# 地表面,796.87
# 地表面,793.05
# 地表面,788.92
# 地表面,785.35
# 地表面,781.86
# 地表面,778.24
# 地表面,775.02
# 地表面,771.89
# 地表面,769.39
# 地表面,766.81
# 地表面,764.14
# 地表面,761.70
# 地表面,758.94
# 地表面,755.82
# 地表面,753.42
# 地表面,751.52
# 地表面,749.40
# 地表面,746.32
# 地表面,743.38
# 地表面,739.38
# 地表面,735.66
# 地表面,731.84
# 地表面,728.02
# 地表面,725.27
# 地表面,725.99
# 地表面,729.17
# 地表面,734.22
# 地表面,738.34
# 地表面,741.52
# 地表面,743.99
# 地表面,745.98
# 地表面,747.42
# 地表面,747.66
# 地表面,747.89
# 地表面,748.78
# 地表面,747.84
# 地表面,744.57
# 地表面,741.13
# 地表面,738.58
# 地表面,737.17
# 地表面,735.25
# 地表面,732.94
# 地表面,730.77
# 地表面,729.41
# 地表面,729.68
# 地表面,732.32
# 地表面,735.10
# 地表面,736.54
# 地表面,738.32
# 地表面,740.37
# 地表面,742.39
# 地表面,744.42
# 地表面,746.22
# 地表面,747.18
# 地表面,746.82
# 地表面,745.20
# 地表面,742.96
# 地表面,740.35
# 地表面,737.60
# 地表面,735.17
# 地表面,733.32
# 地表面,732.44
# 地表面,732.48
# 地表面,732.40
# 地表面,731.31
# 地表面,730.96
# 地表面,732.31
# 地表面,733.36
# 地表面,734.15
# 地表面,735.73
# 地表面,738.30
# 地表面,741.22
# 地表面,744.24
# 地表面,747.08
# 地表面,749.58
# 地表面,751.00
# 地表面,750.25
# 地表面,748.34
# 地表面,746.30
# 地表面,744.04
# 地表面,741.67
# 地表面,739.70
# 地表面,738.14
# 地表面,736.90
# 地表面,736.16
# 地表面,735.69
# 地表面,734.54
# 地表面,733.38
# 地表面,732.34
# 地表面,730.16
# 地表面,726.18
# 地表面,721.51
# 地表面,720.01
# 地表面,722.82
# 地表面,728.38
# 地表面,731.83
# 地表面,732.68
# 地表面,730.32
# 地表面,727.21
# 地表面,723.71
# 地表面,719.86
# 地表面,716.43
# 地表面,716.26
# 地表面,719.74
# 地表面,724.56
# 地表面,729.20
# 地表面,733.83
# 地表面,738.21
# 地表面,742.17
# 地表面,742.54
# 地表面,738.85
# 地表面,733.10
# 地表面,727.96
# 地表面,723.72
# 地表面,720.07
# 地表面,716.40
# 地表面,714.54
# 地表面,713.12
# 地表面,711.70
# 地表面,711.52
# 地表面,714.93
# 地表面,718.39
# 地表面,719.35
# 地表面,711.90
# 地表面,706.39
# 地表面,700.03
# 地表面,694.03
# 地表面,690.21
# 地表面,686.73
# 地表面,683.74
# 地表面,680.17
# 地表面,677.11
# 地表面,674.02
# 地表面,671.67
# 地表面,667.27
# 地表面,662.72
# 地表面,661.34
# 地表面,661.06
# 地表面,660.93
# 地表面,660.75
# 地表面,660.74
# 地表面,660.78
# 地表面,660.67
# 地表面,660.60
# 地表面,838.38
# 地表面,835.25
# 地表面,832.65
# 地表面,829.99
# 地表面,827.14
# 地表面,824.46
# 地表面,821.10
# 地表面,817.01
# 地表面,812.82
# 地表面,808.98
# 地表面,805.80
# 地表面,802.86
# 地表面,799.29
# 地表面,794.91
# 地表面,789.94
# 地表面,785.18
# 地表面,780.15
# 地表面,775.19
# 地表面,772.32
# 地表面,771.75
# 地表面,772.65
# 地表面,775.06
# 地表面,778.03
# 地表面,780.67
# 地表面,782.48
# 地表面,783.91
# 地表面,786.03
# 地表面,788.31
# 地表面,790.10
# 地表面,791.38
# 地表面,792.35
# 地表面,793.17
# 地表面,793.72
# 地表面,794.02
# 地表面,793.71
# 地表面,792.90
# 地表面,792.02
# 地表面,790.81
# 地表面,789.19
# 地表面,787.10
# 地表面,784.47
# 地表面,781.56
# 地表面,778.33
# 地表面,774.36
# 地表面,770.09
# 地表面,766.15
# 地表面,762.32
# 地表面,759.16
# 地表面,756.23
# 地表面,754.50
# 地表面,753.13
# 地表面,752.30
# 地表面,753.85
# 地表面,754.07
# 地表面,753.79
# 地表面,756.19
# 地表面,758.92
# 地表面,761.19
# 地表面,764.05
# 地表面,766.66
# 地表面,768.93
# 地表面,770.91
# 地表面,772.85
# 地表面,774.72
# 地表面,776.48
# 地表面,778.41
# 地表面,780.53
# 地表面,782.65
# 地表面,784.94
# 地表面,787.38
# 地表面,789.98
# 地表面,793.13
# 地表面,795.67
# 地表面,798.00
# 地表面,800.79
# 地表面,803.03
# 地表面,804.45
# 地表面,805.12
# 地表面,805.33
# 地表面,804.48
# 地表面,802.41
# 地表面,798.70
# 地表面,794.53
# 地表面,790.19
# 地表面,786.65
# 地表面,783.31
# 地表面,780.36
# 地表面,778.23
# ...
# 地表面,946.86
# 地表面,944.06
# 地表面,940.54
# 地表面,937.08
# 地表面,936.14
# 地表面,932.92
# 地表面,925.29
# 地表面,922.02
# 地表面,924.92
# 地表面,927.92
# 地表面,929.49
# 地表面,932.61
# 地表面,932.66
# 地表面,932.18
# 地表面,932.87
# 地表面,936.21
# 地表面,939.41
# 地表面,940.23
# 地表面,941.29
# 地表面,942.99
# 地表面,945.24
# 地表面,948.77
# 地表面,951.54
# 地表面,953.65
# 地表面,952.28
# 地表面,953.28
# 地表面,956.47
# 地表面,1012.80
# 地表面,1012.23
# 地表面,1010.77
# 地表面,1009.71
# 地表面,1007.57
# 地表面,1002.85
# 地表面,997.44
# 地表面,991.98
# 地表面,987.03
# 地表面,982.26
# 地表面,976.97
# 地表面,971.01
# 地表面,969.93
# 地表面,971.81
# 地表面,976.14
# 地表面,977.65
# 地表面,977.61
# 地表面,978.29
# 地表面,978.26
# 地表面,977.77
# 地表面,977.70
# 地表面,977.53
# 地表面,978.37
# 地表面,981.11
# 地表面,985.88
# 地表面,990.66
# 地表面,995.84
# 地表面,1000.19
# 地表面,1002.95
# 地表面,1002.66
# 地表面,999.50
# 地表面,996.09
# 地表面,993.27
# 地表面,991.12
# 地表面,989.31
# 地表面,988.41
# 地表面,988.97
# 地表面,989.53
# 地表面,989.74
# 地表面,990.09
# 地表面,990.85
# 地表面,990.12
# 地表面,988.12
# 地表面,988.17
# 地表面,989.98
# 地表面,993.01
# 地表面,996.74
# 地表面,1000.81
# 地表面,1005.84
# 地表面,1010.42
# 地表面,1014.50
# 地表面,1018.16
# 地表面,1021.59
# 地表面,1024.58
# 地表面,1027.44
# 地表面,1029.98
# 地表面,1032.57
# 地表面,1035.64
# 地表面,1038.38
# 地表面,1041.11
# 地表面,1043.94
# 地表面,1046.61
# 地表面,1049.30
# 地表面,1051.97
# 地表面,1054.76
# 地表面,1058.19
# 地表面,1062.51
# 地表面,1066.88
# 地表面,1071.07
# 地表面,1075.44
# 地表面,1079.68
# 地表面,1083.93
# 地表面,1088.22
# 地表面,1092.37
# 地表面,1096.56
# 地表面,1100.57
# 地表面,1104.10
# 地表面,1107.66
# 地表面,1111.56
# 地表面,1115.51
# 地表面,1119.36
# 地表面,1122.77
# 地表面,1125.47
# 地表面,1127.71
# 地表面,1129.84
# 地表面,1131.66
# 地表面,1132.43
# 地表面,1131.60
# 地表面,1129.30
# 地表面,1126.60
# 地表面,1123.68
# 地表面,1121.14
# 地表面,1119.27
# 地表面,1117.30
# 地表面,1115.30
# 地表面,1113.89
# 地表面,1114.14
# 地表面,1115.72
# 地表面,1117.13
# 地表面,1119.01
# 地表面,1121.17
# 地表面,1123.70
# 地表面,1126.17
# 地表面,1128.16
# 地表面,1129.55
# 地表面,1130.17
# 地表面,1130.44
# 地表面,1130.32
# 地表面,1130.13
# 地表面,1130.57
# 地表面,1129.99
# 地表面,1128.14
# 地表面,1126.11
# 地表面,1123.95
# 地表面,1120.98
# 地表面,1117.14
# 地表面,1113.08
# 地表面,1108.85
# 地表面,1104.92
# 地表面,1101.28
# 地表面,1097.02
# 地表面,1091.20
# 地表面,1084.61
# 地表面,1077.64
# 地表面,1072.46
# 地表面,1067.95
# 地表面,1063.43
# 地表面,1059.43
# 地表面,1055.75
# 地表面,1052.19
# 地表面,1048.35
# 地表面,1044.96
# 地表面,1040.59
# 地表面,1035.47
# 地表面,1030.68
# 地表面,1025.08
# 地表面,1019.97
# 地表面,1015.11
# 地表面,1010.38
# 地表面,1006.31
# 地表面,1002.04
# 地表面,997.79
# 地表面,993.89
# 地表面,990.25
# 地表面,987.38
# 地表面,983.77
# 地表面,980.31
# 地表面,977.28
# 地表面,974.05
# 地表面,971.04
# 地表面,969.03
# 地表面,967.73
# 地表面,969.77
# 地表面,974.61
# 地表面,977.83
# 地表面,979.09
# 地表面,980.02
# 地表面,985.42
# 地表面,990.68
# 地表面,995.78
# 地表面,1000.92
# 地表面,1006.09
# 地表面,1010.78
# 地表面,1012.90
# 地表面,1013.21
# 地表面,1015.60
# 地表面,1019.54
# 地表面,1025.17
# 地表面,1031.18
# 地表面,1037.55
# 地表面,1042.66
# 地表面,1046.72
# 地表面,1049.77
# 地表面,1050.43
# 地表面,1048.14
# 地表面,1043.11
# 地表面,1038.94
# 地表面,1037.91
# 地表面,1038.94
# 地表面,1040.62
# 地表面,1039.81
# 地表面,1036.09
# 地表面,1031.44
# 地表面,1026.60
# 地表面,1020.57
# 地表面,1013.47
# 地表面,1006.31
# 地表面,998.63
# 地表面,991.79
# 地表面,986.53
# 地表面,981.58
# 地表面,977.23
# 地表面,974.59
# 地表面,972.66
# 地表面,970.26
# 地表面,967.21
# 地表面,962.88
# 地表面,956.48
# 地表面,950.87
# 地表面,947.00
# 地表面,943.54
# 地表面,941.38
# 地表面,942.21
# 地表面,938.66
# 地表面,931.01
# 地表面,925.94
# 地表面,927.30
# 地表面,931.14
# 地表面,933.98
# 地表面,937.07
# 地表面,938.53
# 地表面,937.85
# 地表面,937.97
# 地表面,939.85
# 地表面,944.60
# 地表面,945.10
# 地表面,945.63
# 地表面,947.54
# 地表面,949.62
# 地表面,952.29
# 地表面,955.52
# 地表面,958.35
# 地表面,959.04
# 地表面,959.20
# 地表面,961.50
# 地表面,1017.41
# 地表面,1018.05
# 地表面,1017.15
# 地表面,1014.95
# 地表面,1010.10
# 地表面,1005.18
# 地表面,1000.20
# 地表面,995.23
# 地表面,990.02
# 地表面,985.14
# 地表面,979.73
# 地表面,973.75
# 地表面,971.19
# 地表面,972.68
# 地表面,976.41
# 地表面,979.08
# 地表面,979.60
# 地表面,980.07
# 地表面,979.98
# 地表面,979.73
# 地表面,979.30
# 地表面,979.20
# 地表面,980.47
# 地表面,983.01
# 地表面,986.91
# 地表面,991.32
# 地表面,996.06
# 地表面,1000.61
# 地表面,1004.23
# 地表面,1005.85
# 地表面,1004.13
# 地表面,1001.24
# 地表面,998.51
# 地表面,995.67
# 地表面,993.50
# 地表面,991.54
# 地表面,990.58
# 地表面,991.07
# 地表面,991.73
# 地表面,992.60
# 地表面,993.44
# 地表面,993.51
# 地表面,992.50
# 地表面,991.25
# 地表面,990.76
# 地表面,991.90
# 地表面,994.67
# 地表面,998.96
# 地表面,1003.52
# 地表面,1008.06
# 地表面,1012.51
# 地表面,1016.83
# 地表面,1020.77
# 地表面,1024.75
# 地表面,1028.73
# 地表面,1032.32
# 地表面,1035.96
# 地表面,1039.70
# 地表面,1042.91
# 地表面,1045.62
# 地表面,1048.19
# 地表面,1050.82
# 地表面,1053.84
# 地表面,1056.79
# 地表面,1059.44
# 地表面,1061.80
# 地表面,1064.03
# 地表面,1066.55
# 地表面,1070.01
# 地表面,1074.28
# 地表面,1078.72
# 地表面,1082.92
# 地表面,1086.94
# 地表面,1091.08
# 地表面,1095.14
# 地表面,1099.13
# 地表面,1102.93
# 地表面,1106.64
# 地表面,1110.68
# 地表面,1114.66
# 地表面,1118.57
# 地表面,1122.31
# 地表面,1125.47
# 地表面,1128.13
# 地表面,1130.58
# 地表面,1132.79
# 地表面,1133.85
# 地表面,1133.23
# 地表面,1131.17
# 地表面,1128.74
# 地表面,1126.24
# 地表面,1123.49
# 地表面,1121.57
# 地表面,1120.33
# 地表面,1118.74
# 地表面,1117.17
# 地表面,1117.78
# 地表面,1119.38
# 地表面,1120.84
# 地表面,1122.10
# 地表面,1124.52
# 地表面,1127.23
# 地表面,1130.33
# 地表面,1132.76
# 地表面,1133.72
# 地表面,1134.15
# 地表面,1134.04
# 地表面,1133.92
# 地表面,1134.46
# 地表面,1134.32
# 地表面,1132.56
# 地表面,1129.93
# 地表面,1127.56
# 地表面,1125.19
# 地表面,1122.46
# 地表面,1119.11
# 地表面,1116.13
# 地表面,1112.21
# 地表面,1108.57
# 地表面,1105.54
# 地表面,1101.23
# 地表面,1091.70
# 地表面,1084.31
# 地表面,1078.63
# 地表面,1073.67
# 地表面,1069.41
# 地表面,1065.26
# 地表面,1061.20
# 地表面,1057.39
# 地表面,1053.02
# 地表面,1048.99
# 地表面,1045.23
# 地表面,1040.82
# 地表面,1036.29
# 地表面,1031.45
# 地表面,1026.27
# 地表面,1020.39
# 地表面,1015.49
# 地表面,1010.57
# 地表面,1006.01
# 地表面,1001.86
# 地表面,998.30
# 地表面,994.09
# 地表面,990.17
# 地表面,986.67
# 地表面,983.59
# 地表面,980.45
# 地表面,977.71
# 地表面,975.35
# 地表面,972.65
# 地表面,970.14
# 地表面,969.73
# 地表面,972.06
# 地表面,976.01
# 地表面,980.53
# 地表面,985.29
# 地表面,984.61
# 地表面,987.17
# 地表面,992.17
# 地表面,997.39
# 地表面,1003.08
# 地表面,1008.88
# 地表面,1013.96
# 地表面,1016.93
# 地表面,1017.34
# 地表面,1019.31
# 地表面,1023.03
# 地表面,1027.91
# 地表面,1033.38
# 地表面,1039.56
# 地表面,1045.50
# 地表面,1049.75
# 地表面,1052.66
# 地表面,1053.90
# 地表面,1053.30
# 地表面,1049.52
# 地表面,1045.56
# 地表面,1044.05
# 地表面,1044.33
# 地表面,1043.77
# 地表面,1041.09
# 地表面,1037.22
# 地表面,1032.44
# 地表面,1027.21
# 地表面,1020.65
# 地表面,1013.72
# 地表面,1007.86
# 地表面,1001.13
# 地表面,994.66
# 地表面,989.95
# 地表面,986.45
# 地表面,982.86
# 地表面,980.00
# 地表面,976.80
# 地表面,972.28
# 地表面,967.51
# 地表面,962.66
# 地表面,957.76
# 地表面,953.50
# 地表面,950.10
# 地表面,947.29
# 地表面,947.16
# 地表面,947.27
# 地表面,943.32
# 地表面,935.47
# 地表面,929.70
# 地表面,930.11
# 地表面,934.26
# 地表面,939.09
# 地表面,943.97
# 地表面,946.64
# 地表面,946.46
# 地表面,944.29
# 地表面,944.28
# 地表面,948.37
# 地表面,949.90
# 地表面,950.57
# 地表面,952.78
# 地表面,954.63
# 地表面,956.50
# 地表面,959.43
# 地表面,962.40
# 地表面,964.74
# 地表面,965.35
# 地表面,966.41
# 地表面,1022.28
# 地表面,1022.68
# 地表面,1022.26
# 地表面,1018.73
# 地表面,1013.30
# 地表面,1008.21
# 地表面,1002.95
# 地表面,997.15
# 地表面,991.31
# 地表面,985.99
# 地表面,980.87
# 地表面,976.28
# 地表面,973.12
# 地表面,973.41
# 地表面,975.63
# 地表面,979.39
# 地表面,980.86
# 地表面,981.19
# 地表面,981.55
# 地表面,981.12
# 地表面,980.58
# 地表面,981.27
# 地表面,982.94
# 地表面,985.13
# 地表面,989.09
# 地表面,992.95
# 地表面,997.24
# 地表面,1001.54
# 地表面,1005.62
# 地表面,1008.62
# 地表面,1008.37
# 地表面,1005.75
# 地表面,1003.15
# 地表面,1000.19
# 地表面,997.94
# 地表面,996.32
# 地表面,994.66
# 地表面,994.01
# 地表面,994.02
# 地表面,994.05
# 地表面,994.79
# 地表面,995.84
# 地表面,996.49
# 地表面,996.64
# 地表面,995.27
# 地表面,993.84
# 地表面,994.05
# 地表面,996.09
# 地表面,1000.20
# 地表面,1005.56
# 地表面,1010.49
# 地表面,1015.18
# 地表面,1019.39
# 地表面,1023.41
# 地表面,1027.55
# 地表面,1031.77
# 地表面,1036.08
# 地表面,1040.88
# 地表面,1045.72
# 地表面,1049.67
# 地表面,1052.69
# 地表面,1055.83
# 地表面,1059.47
# 地表面,1062.27
# 地表面,1064.61
# 地表面,1067.10
# 地表面,1069.56
# 地表面,1071.73
# 地表面,1073.68
# 地表面,1075.93
# 地表面,1079.00
# 地表面,1082.50
# 地表面,1086.12
# 地表面,1090.05
# 地表面,1094.16
# 地表面,1098.18
# 地表面,1102.24
# 地表面,1106.16
# 地表面,1109.97
# 地表面,1114.01
# 地表面,1118.16
# 地表面,1122.02
# 地表面,1125.61
# 地表面,1128.75
# 地表面,1131.56
# 地表面,1133.99
# 地表面,1135.58
# 地表面,1135.41
# 地表面,1133.59
# 地表面,1131.13
# 地表面,1128.61
# 地表面,1126.31
# 地表面,1124.50
# 地表面,1123.20
# 地表面,1121.86
# 地表面,1120.69
# 地表面,1121.31
# 地表面,1122.83
# 地表面,1123.97
# 地表面,1125.35
# 地表面,1127.53
# 地表面,1130.39
# 地表面,1133.70
# 地表面,1136.33
# 地表面,1137.31
# 地表面,1137.42
# 地表面,1137.60
# 地表面,1137.37
# 地表面,1136.89
# 地表面,1136.06
# 地表面,1134.21
# 地表面,1131.47
# 地表面,1129.13
# 地表面,1126.22
# 地表面,1123.52
# 地表面,1120.56
# 地表面,1117.02
# 地表面,1113.39
# 地表面,1109.53
# 地表面,1105.26
# 地表面,1094.60
# 地表面,1089.83
# 地表面,1084.65
# 地表面,1079.25
# 地表面,1074.69
# 地表面,1069.78
# 地表面,1065.25
# 地表面,1060.99
# 地表面,1056.56
# 地表面,1051.94
# 地表面,1047.80
# 地表面,1044.00
# 地表面,1040.17
# 地表面,1036.05
# 地表面,1031.61
# 地表面,1026.38
# 地表面,1019.46
# 地表面,1014.78
# 地表面,1010.92
# 地表面,1008.28
# 地表面,1005.47
# 地表面,1001.59
# 地表面,995.56
# 地表面,990.46
# 地表面,986.35
# 地表面,983.37
# 地表面,980.14
# 地表面,977.19
# 地表面,975.55
# 地表面,973.56
# 地表面,972.17
# 地表面,971.89
# 地表面,974.51
# 地表面,978.53
# 地表面,982.32
# 地表面,987.09
# 地表面,990.07
# 地表面,990.32
# 地表面,994.19
# 地表面,1000.35
# 地表面,1006.19
# 地表面,1012.05
# 地表面,1017.58
# 地表面,1020.99
# 地表面,1021.77
# 地表面,1023.24
# 地表面,1026.07
# 地表面,1029.51
# 地表面,1033.97
# 地表面,1039.25
# 地表面,1045.05
# 地表面,1050.16
# 地表面,1053.88
# 地表面,1056.60
# 地表面,1057.94
# 地表面,1055.72
# 地表面,1052.13
# 地表面,1050.30
# 地表面,1049.46
# 地表面,1046.78
# 地表面,1042.48
# 地表面,1038.26
# 地表面,1033.20
# 地表面,1026.85
# 地表面,1019.89
# 地表面,1014.11
# 地表面,1008.97
# 地表面,1003.52
# 地表面,999.04
# 地表面,994.72
# 地表面,990.38
# 地表面,985.94
# 地表面,981.45
# 地表面,976.89
# 地表面,971.73
# 地表面,967.10
# 地表面,963.25
# 地表面,959.88
# 地表面,956.77
# 地表面,953.61
# 地表面,950.96
# 地表面,951.93
# 地表面,951.44
# 地表面,945.64
# 地表面,937.86
# 地表面,933.54
# 地表面,933.88
# 地表面,939.12
# 地表面,945.74
# 地表面,951.18
# 地表面,954.59
# 地表面,956.48
# 地表面,952.92
# 地表面,949.70
# 地表面,950.88
# 地表面,955.23
# 地表面,956.66
# 地表面,960.82
# 地表面,962.19
# 地表面,964.68
# 地表面,970.40
# 地表面,970.62
# 地表面,970.19
# 地表面,970.25
# 地表面,970.36
# 地表面,1027.56
# 地表面,1027.59
# 地表面,1026.65
# 地表面,1022.16
# 地表面,1016.57
# 地表面,1010.28
# 地表面,1004.00
# 地表面,997.25
# 地表面,992.44
# 地表面,988.38
# 地表面,983.11
# 地表面,979.14
# 地表面,975.65
# 地表面,974.42
# 地表面,975.01
# 地表面,977.96
# 地表面,981.79
# 地表面,983.50
# 地表面,982.99
# 地表面,982.13
# 地表面,981.92
# 地表面,983.69
# 地表面,985.05
# 地表面,986.84
# 地表面,990.58
# 地表面,994.52
# 地表面,998.56
# 地表面,1002.87
# 地表面,1007.29
# 地表面,1010.90
# 地表面,1012.19
# 地表面,1010.23
# 地表面,1007.41
# 地表面,1004.87
# 地表面,1002.81
# 地表面,1001.24
# 地表面,999.59
# 地表面,998.28
# 地表面,997.52
# 地表面,996.57
# 地表面,996.43
# 地表面,997.42
# 地表面,998.44
# 地表面,999.34
# 地表面,999.63
# 地表面,998.72
# 地表面,997.28
# 地表面,996.61
# 地表面,998.68
# 地表面,1003.70
# 地表面,1008.93
# 地表面,1013.48
# 地表面,1017.90
# 地表面,1022.48
# 地表面,1026.89
# 地表面,1031.08
# 地表面,1035.32
# 地表面,1039.86
# 地表面,1044.54
# 地表面,1049.18
# 地表面,1053.64
# 地表面,1058.12
# 地表面,1062.68
# 地表面,1066.57
# 地表面,1069.74
# 地表面,1072.75
# 地表面,1075.15
# 地表面,1076.89
# 地表面,1078.72
# 地表面,1080.64
# 地表面,1082.59
# 地表面,1084.68
# 地表面,1087.32
# 地表面,1090.54
# 地表面,1094.00
# 地表面,1097.62
# 地表面,1101.31
# 地表面,1105.18
# 地表面,1109.11
# 地表面,1113.33
# 地表面,1117.55
# 地表面,1121.65
# 地表面,1125.60
# 地表面,1129.23
# 地表面,1132.40
# 地表面,1135.14
# 地表面,1137.17
# 地表面,1137.44
# 地表面,1135.99
# 地表面,1133.69
# 地表面,1131.30
# 地表面,1129.16
# 地表面,1127.65
# 地表面,1126.59
# 地表面,1125.60
# 地表面,1124.58
# 地表面,1124.98
# 地表面,1126.37
# 地表面,1127.65
# 地表面,1129.20
# 地表面,1131.10
# 地表面,1133.59
# 地表面,1136.56
# 地表面,1139.38
# 地表面,1140.29
# 地表面,1140.45
# 地表面,1140.50
# 地表面,1139.91
# 地表面,1138.84
# 地表面,1137.46
# 地表面,1135.37
# 地表面,1133.01
# 地表面,1130.17
# 地表面,1127.10
# 地表面,1124.07
# 地表面,1121.12
# 地表面,1116.86
# 地表面,1113.21
# 地表面,1109.03
# 地表面,1103.74
# 地表面,1097.03
# 地表面,1090.69
# 地表面,1084.65
# 地表面,1079.59
# 地表面,1074.88
# 地表面,1070.14
# 地表面,1065.51
# 地表面,1061.07
# 地表面,1056.52
# 地表面,1050.61
# 地表面,1047.01
# 地表面,1042.60
# 地表面,1038.53
# 地表面,1034.85
# 地表面,1031.13
# 地表面,1026.82
# 地表面,1022.51
# 地表面,1018.95
# 地表面,1015.24
# 地表面,1012.77
# 地表面,1010.57
# 地表面,1005.99
# 地表面,999.10
# 地表面,990.67
# 地表面,985.56
# 地表面,982.51
# 地表面,980.01
# 地表面,977.63
# 地表面,975.54
# 地表面,973.71
# 地表面,973.32
# 地表面,974.60
# 地表面,977.32
# 地表面,981.41
# 地表面,984.34
# 地表面,988.36
# 地表面,993.71
# 地表面,995.75
# 地表面,998.17
# 地表面,1003.71
# 地表面,1008.61
# 地表面,1014.53
# 地表面,1021.50
# 地表面,1024.87
# 地表面,1025.56
# 地表面,1026.87
# 地表面,1029.38
# 地表面,1032.34
# 地表面,1036.61
# 地表面,1041.98
# 地表面,1047.24
# 地表面,1051.60
# 地表面,1055.44
# 地表面,1059.31
# 地表面,1061.80
# 地表面,1060.64
# 地表面,1057.75
# 地表面,1055.86
# 地表面,1053.11
# 地表面,1047.83
# 地表面,1043.03
# 地表面,1038.74
# 地表面,1033.99
# 地表面,1027.84
# 地表面,1021.21
# 地表面,1015.45
# 地表面,1010.61
# 地表面,1005.62
# 地表面,999.40
# 地表面,994.58
# 地表面,990.43
# 地表面,985.16
# 地表面,980.36
# 地表面,976.43
# 地表面,972.45
# 地表面,969.08
# 地表面,966.05
# 地表面,963.04
# 地表面,960.23
# 地表面,957.07
# 地表面,955.26
# 地表面,955.75
# 地表面,953.39
# 地表面,948.40
# 地表面,940.96
# 地表面,937.55
# 地表面,936.48
# 地表面,940.64
# 地表面,947.64
# 地表面,954.03
# 地表面,959.50
# 地表面,964.06
# 地表面,966.63
# 地表面,965.31
# 地表面,960.69
# 地表面,961.34
# 地表面,965.18
# 地表面,972.71
# 地表面,975.15
# 地表面,979.45
# 地表面,984.37
# 地表面,985.13
# 地表面,982.06
# 地表面,976.44
# 地表面,969.65
# 地表面,1033.03
# 地表面,1032.10
# 地表面,1028.63
# 地表面,1024.09
# 地表面,1017.99
# 地表面,1011.91
# 地表面,1004.71
# 地表面,999.93
# 地表面,996.89
# 地表面,993.04
# 地表面,987.74
# 地表面,983.56
# 地表面,980.04
# 地表面,977.38
# 地表面,975.70
# 地表面,977.31
# 地表面,980.25
# 地表面,984.16
# 地表面,985.12
# 地表面,983.83
# 地表面,983.30
# 地表面,985.50
# 地表面,987.33
# 地表面,988.44
# 地表面,991.84
# 地表面,995.84
# 地表面,1000.06
# 地表面,1004.32
# 地表面,1008.59
# 地表面,1012.42
# 地表面,1014.80
# 地表面,1014.47
# 地表面,1012.85
# 地表面,1010.08
# 地表面,1007.58
# 地表面,1005.87
# 地表面,1004.15
# 地表面,1003.08
# 地表面,1002.18
# 地表面,1000.70
# 地表面,999.67
# 地表面,999.21
# 地表面,1000.24
# 地表面,1001.42
# 地表面,1002.13
# 地表面,1002.46
# 地表面,1001.69
# 地表面,999.52
# 地表面,999.44
# 地表面,1003.09
# 地表面,1007.98
# 地表面,1012.54
# 地表面,1017.23
# 地表面,1021.97
# 地表面,1026.42
# 地表面,1030.65
# 地表面,1035.05
# 地表面,1039.70
# 地表面,1044.28
# 地表面,1048.90
# 地表面,1053.38
# 地表面,1058.01
# 地表面,1062.57
# 地表面,1067.06
# 地表面,1071.42
# 地表面,1075.12
# 地表面,1078.52
# 地表面,1081.56
# 地表面,1083.83
# 地表面,1085.77
# 地表面,1087.50
# 地表面,1089.04
# 地表面,1090.97
# 地表面,1093.36
# 地表面,1096.13
# 地表面,1099.18
# 地表面,1102.42
# 地表面,1105.87
# 地表面,1109.59
# 地表面,1113.28
# 地表面,1116.93
# 地表面,1121.34
# 地表面,1125.68
# 地表面,1129.69
# 地表面,1133.28
# 地表面,1136.36
# 地表面,1138.69
# 地表面,1139.44
# 地表面,1138.27
# 地表面,1136.34
# 地表面,1134.30
# 地表面,1132.44
# 地表面,1131.05
# 地表面,1129.95
# 地表面,1129.35
# 地表面,1128.38
# 地表面,1128.51
# 地表面,1130.07
# 地表面,1131.94
# 地表面,1133.61
# 地表面,1135.41
# 地表面,1137.47
# 地表面,1139.89
# 地表面,1142.12
# 地表面,1143.09
# 地表面,1143.38
# 地表面,1143.25
# 地表面,1142.62
# 地表面,1141.34
# 地表面,1139.31
# 地表面,1136.92
# 地表面,1134.20
# 地表面,1130.81
# 地表面,1127.53
# 地表面,1124.26
# 地表面,1120.93
# 地表面,1116.60
# 地表面,1113.90
# 地表面,1109.49
# 地表面,1104.32
# 地表面,1098.76
# 地表面,1092.28
# 地表面,1086.35
# 地表面,1081.07
# 地表面,1076.45
# 地表面,1070.88
# 地表面,1065.94
# 地表面,1061.32
# 地表面,1056.41
# 地表面,1053.04
# 地表面,1051.45
# 地表面,1046.13
# 地表面,1041.28
# 地表面,1037.78
# 地表面,1034.53
# 地表面,1030.71
# 地表面,1026.66
# 地表面,1022.65
# 地表面,1018.99
# 地表面,1015.77
# 地表面,1011.96
# 地表面,1006.60
# 地表面,998.75
# 地表面,990.27
# 地表面,985.79
# 地表面,983.24
# 地表面,980.94
# 地表面,978.28
# 地表面,976.00
# 地表面,975.47
# 地表面,976.39
# 地表面,978.51
# 地表面,981.33
# 地表面,983.87
# 地表面,987.14
# 地表面,990.48
# 地表面,995.25
# 地表面,999.51
# 地表面,1003.04
# 地表面,1007.54
# 地表面,1011.77
# 地表面,1016.82
# 地表面,1023.38
# 地表面,1029.05
# 地表面,1030.17
# 地表面,1030.02
# 地表面,1032.24
# 地表面,1035.38
# 地表面,1039.36
# 地表面,1044.28
# 地表面,1049.05
# 地表面,1053.52
# 地表面,1057.44
# 地表面,1061.24
# 地表面,1064.40
# 地表面,1065.00
# 地表面,1063.19
# 地表面,1060.13
# 地表面,1055.14
# 地表面,1049.55
# 地表面,1044.18
# 地表面,1038.93
# 地表面,1034.14
# 地表面,1028.82
# 地表面,1022.93
# 地表面,1016.24
# 地表面,1009.31
# 地表面,1003.39
# 地表面,998.45
# 地表面,994.22
# 地表面,990.13
# 地表面,986.07
# 地表面,982.33
# 地表面,978.79
# 地表面,975.36
# 地表面,972.04
# 地表面,968.81
# 地表面,965.89
# 地表面,963.08
# 地表面,960.16
# 地表面,959.85
# 地表面,958.83
# 地表面,954.52
# 地表面,949.38
# 地表面,943.32
# 地表面,942.70
# 地表面,940.71
# 地表面,939.98
# 地表面,944.91
# 地表面,953.26
# 地表面,960.71
# 地表面,967.78
# 地表面,973.81
# 地表面,977.06
# 地表面,974.50
# 地表面,968.96
# 地表面,969.68
# 地表面,975.67
# 地表面,981.08
# 地表面,986.19
# 地表面,989.25
# 地表面,988.40
# 地表面,984.11
# 地表面,975.90
# 地表面,967.77
# 地表面,1036.83
# 地表面,1033.26
# 地表面,1027.63
# 地表面,1022.84
# 地表面,1017.74
# 地表面,1011.86
# 地表面,1007.76
# 地表面,1006.06
# 地表面,1001.40
# 地表面,996.77
# 地表面,992.65
# 地表面,988.26
# 地表面,984.76
# 地表面,981.73
# 地表面,978.93
# 地表面,978.90
# 地表面,980.80
# 地表面,984.33
# 地表面,987.77
# 地表面,986.61
# 地表面,985.58
# 地表面,987.25
# 地表面,988.93
# 地表面,989.83
# 地表面,992.98
# 地表面,996.36
# 地表面,1000.58
# 地表面,1005.15
# 地表面,1009.29
# 地表面,1013.36
# 地表面,1016.89
# 地表面,1018.70
# 地表面,1017.83
# 地表面,1015.32
# 地表面,1012.63
# 地表面,1010.09
# 地表面,1008.68
# 地表面,1007.65
# 地表面,1006.37
# 地表面,1004.95
# 地表面,1003.63
# 地表面,1002.63
# 地表面,1002.18
# 地表面,1002.51
# 地表面,1003.65
# 地表面,1004.97
# 地表面,1004.71
# 地表面,1002.17
# 地表面,1000.40
# 地表面,1003.10
# 地表面,1007.91
# 地表面,1012.15
# 地表面,1016.48
# 地表面,1021.02
# 地表面,1025.75
# 地表面,1030.29
# 地表面,1034.98
# 地表面,1039.92
# 地表面,1044.44
# 地表面,1048.81
# 地表面,1053.13
# 地表面,1057.31
# 地表面,1061.39
# 地表面,1065.37
# 地表面,1069.31
# 地表面,1073.41
# 地表面,1077.76
# 地表面,1082.28
# 地表面,1086.72
# 地表面,1090.40
# 地表面,1092.92
# 地表面,1094.27
# 地表面,1095.35
# 地表面,1096.98
# 地表面,1099.65
# 地表面,1102.89
# 地表面,1105.81
# 地表面,1108.66
# 地表面,1111.98
# 地表面,1115.50
# 地表面,1119.08
# 地表面,1122.40
# 地表面,1126.17
# 地表面,1130.41
# 地表面,1134.30
# 地表面,1137.66
# 地表面,1140.14
# 地表面,1141.30
# 地表面,1140.59
# 地表面,1138.98
# 地表面,1137.31
# 地表面,1135.83
# 地表面,1134.62
# 地表面,1133.72
# 地表面,1132.92
# 地表面,1131.65
# 地表面,1132.06
# 地表面,1134.14
# 地表面,1136.21
# 地表面,1138.34
# 地表面,1140.27
# 地表面,1142.48
# 地表面,1144.63
# 地表面,1145.87
# 地表面,1146.31
# 地表面,1146.07
# 地表面,1145.78
# 地表面,1144.96
# 地表面,1143.45
# 地表面,1141.35
# 地表面,1138.54
# 地表面,1135.55
# 地表面,1131.80
# 地表面,1128.11
# 地表面,1123.63
# 地表面,1119.93
# 地表面,1116.24
# 地表面,1112.45
# 地表面,1107.54
# 地表面,1102.74
# 地表面,1098.34
# 地表面,1093.29
# 地表面,1089.13
# 地表面,1082.33
# 地表面,1077.57
# 地表面,1071.05
# 地表面,1065.92
# 地表面,1062.09
# 地表面,1060.15
# 地表面,1058.33
# 地表面,1054.57
# 地表面,1046.66
# 地表面,1043.04
# 地表面,1040.01
# 地表面,1037.21
# 地表面,1033.41
# 地表面,1028.88
# 地表面,1023.97
# 地表面,1019.43
# 地表面,1014.96
# 地表面,1010.03
# 地表面,1003.87
# 地表面,996.33
# 地表面,989.64
# 地表面,986.80
# 地表面,984.32
# 地表面,981.13
# 地表面,978.49
# 地表面,977.54
# 地表面,978.41
# 地表面,980.24
# 地表面,983.25
# 地表面,985.94
# 地表面,988.21
# 地表面,990.46
# 地表面,992.92
# 地表面,996.27
# 地表面,1000.23
# 地表面,1004.45
# 地表面,1009.71
# 地表面,1014.90
# 地表面,1019.56
# 地表面,1026.08
# 地表面,1033.76
# 地表面,1036.36
# 地表面,1034.50
# 地表面,1035.16
# 地表面,1037.94
# 地表面,1041.40
# 地表面,1045.57
# 地表面,1050.23
# 地表面,1054.74
# 地表面,1058.96
# 地表面,1062.63
# 地表面,1065.83
# 地表面,1067.68
# 地表面,1066.67
# 地表面,1062.94
# 地表面,1057.76
# 地表面,1052.78
# 地表面,1047.44
# 地表面,1041.57
# 地表面,1036.15
# 地表面,1031.08
# 地表面,1026.06
# 地表面,1020.03
# 地表面,1012.64
# 地表面,1005.38
# 地表面,999.70
# 地表面,995.23
# 地表面,991.32
# 地表面,987.61
# 地表面,983.89
# 地表面,980.55
# 地表面,977.38
# 地表面,974.22
# 地表面,971.15
# 地表面,968.42
# 地表面,965.71
# 地表面,963.65
# 地表面,964.18
# 地表面,964.43
# 地表面,962.38
# 地表面,956.72
# 地表面,949.16
# 地表面,950.41
# 地表面,948.38
# 地表面,943.73
# 地表面,947.13
# 地表面,957.50
# 地表面,966.13
# 地表面,974.14
# 地表面,980.47
# 地表面,983.23
# 地表面,981.31
# 地表面,977.88
# 地表面,976.21
# 地表面,979.78
# 地表面,984.73
# 地表面,990.18
# 地表面,992.57
# 地表面,990.53
# 地表面,984.91
# 地表面,974.66
# 地表面,966.65

# %% [markdown]
# 標高値が格納されている文字列はcsvそのものになっており，
# csvとして書き出せばpandasの`pd.read_csv()`でデータフレームに読み込むことができます．
#
# しかし，一旦ファイルに書き出して再度読み込むのも煩雑なため，`io.StringIO`を使ってテキストストリームを作成し，これにpandasの`pd.read_csv`を組み合わせてcsv型式の文字列をデータフレームに格納します．
# ついでに列名`att`と`z`も加えます．

# %%
df = pd.read_csv(io.StringIO(tuplelist.text), header = None)
df.columns = ['att', 'z']
df
# Out:
#        att       z
# 0      地表面  811.38
# 1      地表面  810.34
# 2      地表面  807.94
# 3      地表面  804.86
# 4      地表面  801.37
# ...    ...     ...
# 33745  地表面  992.57
# 33746  地表面  990.53
# 33747  地表面  984.91
# 33748  地表面  974.66
# 33749  地表面  966.65
#
# [33750 rows x 2 columns]

# %% [markdown]
# データフレームの大きさは21165行 $\times$ 2列になっています．
# 5mメッシュDEMの場合，格納されている標高値の列数と行数は`gml:high`と`gml:low`によって規定されています．
# 両者を取得して確認してみましょう．

# %%
print(elem.find(".//gml:low", ns).text)
print(elem.find(".//gml:high", ns).text)
# Out:
# 0 0
# 224 149

# %% [markdown]
# (0, 0)から(224, 149)の225列 $\times$ 150行の合計33376個になっています．
# しかし，実際には21165個のデータしかありません．
# これは，海面などで標高値がない部分が連続する場合，データが省略されていることが原因です．
# データの開始地点は`gml:startPoint`に格納されています．

# %%
print(elem.find('.//gml:startPoint', ns).text)
# Out:
# 0 0

# %% [markdown]
# `gml:startPoint`を見てみると，標高値は155列12行から格納されていることがわかります．
# しかし，$(225-155)+((150-12)\times225)$の31120個のデータがあるはずですが，
# 実際には21165メッシュ分しかありません．
# `gml:startPoint`はあくまでもデータの格納開始地点を表しているにすぎず，終了地点を表すタグはないので，
# 不足分はデータが省略されています．

# %% [markdown]
# # 標高配列の作成

# %% [markdown]
# ## 標高データに通し番号をつける

# %% [markdown]
# `df`に格納されている標高値にメッシュの通し番号をつけます．
# この通し番号は省略されたデータも含むものとします．
#
# メッシュの初期値は`開始列番号+(開始行番号*列数)`です．
# 開始列番号と開始行番号は`gml:startPoint`から取得します．
# `gml:startPoint`の値はスペースで区切られており，
# スペースの前が開始列番号，後ろが開始行番号です．
# 開始列番号を`startPointX`，開始行番号を`startPointY`とし，
# `split`メソッドを使って分割します．
# 分割されて取得されるリストは文字列になっていますので，
# `int`関数を使って整数値に変換します．

# %%
startPoint = elem.find('.//gml:startPoint', ns).text.split(' ')
startPointX = int(startPoint[0])
startPointY = int(startPoint[1])
print(startPointX, startPointY)
# Out:
# 0 0

# %% [markdown]
# 行数と列数は`gml:high`から取得できます．
# `gml:high`も行数と列数がスペースで区切られているので，
# `split(' ')`で値を分割します．区切られた値はリストになりますので，
# 最初の要素`[0]`である列数を整数化して変数`cols`に代入します．
# 同様に2番目の要素`[1]`の行数を整数化して`rows`に代入します．

# %%
cols = int(elem.find(".//gml:high", ns).text.split(' ')[0]) + 1
rows = int(elem.find(".//gml:high", ns).text.split(' ')[1]) + 1
print(rows, cols)
# Out:
# 150 225

# %% [markdown]
# 開始番号`start`は`startPointX + (列数 * startPointY)`で，
# 終了番号`end`は開始番号に`df`の行数を加えたものになります．
# `df`の行数は`df.shape[0]`で取得できます．

# %%
start = startPointX + (cols * startPointY)
end = int(df.shape[0]) + start
print(start, end)
# Out:
# 0 33750

# %% [markdown]
# 次に`range`関数を使って，標高値のあるメッシュの通し番号のリスト`n`を作成します．

# %%
n = list(range(start, end))
len(n)
# Out:
# 33750

# %% [markdown]
# 標高を格納したデータフレーム`df`にリスト`n`を加えます．

# %%
df['n'] = n
df
# Out:
#        att       z      n
# 0      地表面  811.38      0
# 1      地表面  810.34      1
# 2      地表面  807.94      2
# 3      地表面  804.86      3
# 4      地表面  801.37      4
# ...    ...     ...    ...
# 33745  地表面  992.57  33745
# 33746  地表面  990.53  33746
# 33747  地表面  984.91  33747
# 33748  地表面  974.66  33748
# 33749  地表面  966.65  33749
#
# [33750 rows x 3 columns]

# %% [markdown]
# ## 標高値の通し番号から列番号と行番号を求める

# %% [markdown]
# 通し番号`n`の値から列番号`x4`と行番号`y4`を求めます．
# `n`を列数`cols`で割った余りが列番号，
# 商の整数部が行番号になります．
# 剰余を求める演算子`%`と整数の商を求める`//`を利用します．
# 求めた列番号と行番号はそれぞれ`x4`と`y4`としてデータフレーム`df`に格納します．

# %%
df['x4'] = (df['n'] % cols)
df['y4'] = (df['n'] // cols)
df
# Out:
#        att       z      n   x4   y4
# 0      地表面  811.38      0    0    0
# 1      地表面  810.34      1    1    0
# 2      地表面  807.94      2    2    0
# 3      地表面  804.86      3    3    0
# 4      地表面  801.37      4    4    0
# ...    ...     ...    ...  ...  ...
# 33745  地表面  992.57  33745  220  149
# 33746  地表面  990.53  33746  221  149
# 33747  地表面  984.91  33747  222  149
# 33748  地表面  974.66  33748  223  149
# 33749  地表面  966.65  33749  224  149
#
# [33750 rows x 5 columns]

# %% [markdown]
# ## 標高値にユニークな列番号と行番号をつける

# %% [markdown]
# 次に各標高点の1次メッシュから3次メッシュまでの列番号と行番号を求めます．
#
# メッシュコードが格納されているのは`mesh.text`で，これは以前に取得しています．
# `mesh.text`は8桁の数字からなっており，
# 最初の4桁が1時メッシュコード，
# 次の2桁が2次メッシュコード，
# 最後の2桁が3次メッシュコードです．
#
# 1次メッシュコードから3次メッシュコードの構成は以下のようになっています．
#
# * 1次メッシュコード
#
# 5039|5040|5041|$\ldots$
# -|-|-|-
# 4939|4940|4941|$\ldots$
# 4839|4840|4841|$\ldots$
# 4739|4740|4741|$\ldots$
# $\vdots$|$\vdots$|$\vdots$|$\ddots$
#
# * 2次メッシュコード
#
# 70|71|72|73|$\ldots$|77
# -|-|-|-|-|-|
# 60|61|62|63|$\ldots$|67
# 50|51|52|53|$\ldots$|57
# $\vdots$|$\vdots$|$\vdots$|$\vdots$|$\ddots$|$\vdots$
# 00|01|02|03|$\ldots$|07
#
# * 3次メッシュコード
#
# 90|91|92|93|$\ldots$|99
# -|-|-|-|-|-|
# 80|81|82|83|$\ldots$|89
# 70|71|72|73|$\ldots$|79
# $\vdots$|$\vdots$|$\vdots$|$\vdots$|$\ddots$|$\vdots$
# 00|01|02|03|$\ldots$|09
#
# 1次メッシュの中には2次メッシュが8 $\times$ 8メッシュ，
# 2次メッシュの中には3次メッシュが10 $\times$ 10メッシュ入っています．
# さらに3次メッシュの中には標高点が`cols`$\times$ `rows`個あります．
# つまり，1次メッシュの中には$(8\times 10\times cols) \times (8 \times 10 \times rows)$個の標高点が格納されています．
#
# 1次メッシュから3次メッシュまでのxとyを取得します．

# %%
y1 = int(mesh.text[0:2])
x1 = int(mesh.text[2:4])
y2 = int(mesh.text[4])
x2 = int(mesh.text[5])
y3 = int(mesh.text[6])
x3 = int(mesh.text[7])

# %% [markdown]
# 取得した1次メッシュから3次メッシュのxとyをデータフレームに追加します．

# %%
df['x1'] = x1
df['y1'] = y1
df['x2'] = x2
df['y2'] = y2
df['x3'] = x3
df['y3'] = y3
df
# Out:
#        att       z      n   x4   y4  x1  y1  x2  y2  x3  y3
# 0      地表面  811.38      0    0    0  38  53   7   2   0   0
# 1      地表面  810.34      1    1    0  38  53   7   2   0   0
# 2      地表面  807.94      2    2    0  38  53   7   2   0   0
# 3      地表面  804.86      3    3    0  38  53   7   2   0   0
# 4      地表面  801.37      4    4    0  38  53   7   2   0   0
# ...    ...     ...    ...  ...  ...  ..  ..  ..  ..  ..  ..
# 33745  地表面  992.57  33745  220  149  38  53   7   2   0   0
# 33746  地表面  990.53  33746  221  149  38  53   7   2   0   0
# 33747  地表面  984.91  33747  222  149  38  53   7   2   0   0
# 33748  地表面  974.66  33748  223  149  38  53   7   2   0   0
# 33749  地表面  966.65  33749  224  149  38  53   7   2   0   0
#
# [33750 rows x 11 columns]

# %% [markdown]
# 次に`x1`〜`x4`，`y1`〜`y4`を使って，1次メッシュをまたぐような列番号`x`と行番号`y`を作成します．

# %%
df['x'] = df['x4'] + (df['x3'] * cols) + (df['x2'] * 10 * cols) + (df['x1'] * 8 * 10 * cols)
df['y'] = df['y4'] + ((8 - df['y3']) * rows) + ((10 - df['y2']) * 10 * rows) + ((100 - df['y1']) * 8 * 10 * rows)
df
# Out:
#        att       z      n   x4   y4  x1  y1  x2  y2  x3  y3       x       y
# 0      地表面  811.38      0    0    0  38  53   7   2   0   0  699750  577200
# 1      地表面  810.34      1    1    0  38  53   7   2   0   0  699751  577200
# 2      地表面  807.94      2    2    0  38  53   7   2   0   0  699752  577200
# 3      地表面  804.86      3    3    0  38  53   7   2   0   0  699753  577200
# 4      地表面  801.37      4    4    0  38  53   7   2   0   0  699754  577200
# ...    ...     ...    ...  ...  ...  ..  ..  ..  ..  ..  ..     ...     ...
# 33745  地表面  992.57  33745  220  149  38  53   7   2   0   0  699970  577349
# 33746  地表面  990.53  33746  221  149  38  53   7   2   0   0  699971  577349
# 33747  地表面  984.91  33747  222  149  38  53   7   2   0   0  699972  577349
# 33748  地表面  974.66  33748  223  149  38  53   7   2   0   0  699973  577349
# 33749  地表面  966.65  33749  224  149  38  53   7   2   0   0  699974  577349
#
# [33750 rows x 13 columns]

# %% [markdown]
# ## 標高値ごとの緯度経度座標を求める

# %% [markdown]
# 念のため，標高値それぞれの緯度経度も求めましょう．
# まず，処理中のファイルの北西端の緯度経度を取得します．
# これは`gml:upperCorner`と`gml:lowerCorner`から取得できます．
# `gml:upperCorner`と`gml:lowerCorner`はそれぞれ北東端と南西端の座標を示しており，スペースで区切られています．
# `split()`使って緯度と経度を分割してリスト化し，左上X（`ULX`，Upper Left X），左上Y（`ULY`），右下X（`LRX`，Lower Right X），右下Y（`LRY`）を`float()`として実数にキャストして格納します．

# %%
uppercorner = elem.find('.//gml:upperCorner', ns)
lowercorner = elem.find('.//gml:lowerCorner', ns)

ULX = float(lowercorner.text.split(' ')[1])
ULY = float(uppercorner.text.split(' ')[0])
LRX = float(uppercorner.text.split(' ')[1])
LRY = float(lowercorner.text.split(' ')[0])
print(ULX, ULY, LRX, LRY)
# Out:
# 138.875 35.508333333 138.8875 35.5

# %% [markdown]
# 次に標高値ひとつあたりのX方向の長さ（単位は十進経度）とY方向の長さ（単位は十進緯度）を求めます．
# X方向の長さは右側経度`LRX`と左側経度`ULX`の差を東西メッシュ数`cols`で割ったものになります．
# 同様にY方向の長さは上側緯度`ULY`と下側緯度`LRY`の差を南北メッシュ数`rows`で割ったものになります．それぞれ`Xsize`と`Ysize`とします．

# %%
Xsize = (LRX - ULX) / cols
Ysize = (ULY - LRY) / rows
print(Xsize, Ysize)
# Out:
# 5.555555555550503e-05 5.555555333335368e-05

# %% [markdown]
# 緯度経度を計算します．
# 経度は左側経度（`ULX`）に`x4`を足して標高値1つあたりの経度幅`Xsize`）を掛けたものになります．
# 緯度は上側緯度（`ULY`）から`y4`を引いたものに標高値一つあたりの緯度幅`Ysize`を掛けたものになります．

# %%
df['lon'] = ULX + df['x4'] * Xsize
df['lat'] = ULY - df['y4'] * Ysize
df
# Out:
#        att       z      n   x4   y4  x1  y1  x2  y2  x3  y3       x       y  \
# 0      地表面  811.38      0    0    0  38  53   7   2   0   0  699750  577200
# 1      地表面  810.34      1    1    0  38  53   7   2   0   0  699751  577200
# 2      地表面  807.94      2    2    0  38  53   7   2   0   0  699752  577200
# 3      地表面  804.86      3    3    0  38  53   7   2   0   0  699753  577200
# 4      地表面  801.37      4    4    0  38  53   7   2   0   0  699754  577200
# ...    ...     ...    ...  ...  ...  ..  ..  ..  ..  ..  ..     ...     ...
# 33745  地表面  992.57  33745  220  149  38  53   7   2   0   0  699970  577349
# 33746  地表面  990.53  33746  221  149  38  53   7   2   0   0  699971  577349
# 33747  地表面  984.91  33747  222  149  38  53   7   2   0   0  699972  577349
# 33748  地表面  974.66  33748  223  149  38  53   7   2   0   0  699973  577349
# 33749  地表面  966.65  33749  224  149  38  53   7   2   0   0  699974  577349
#
#               lon        lat
# 0      138.875000  35.508333
# 1      138.875056  35.508333
# 2      138.875111  35.508333
# 3      138.875167  35.508333
# 4      138.875222  35.508333
# ...           ...        ...
# 33745  138.887222  35.500056
# 33746  138.887278  35.500056
# 33747  138.887333  35.500056
# 33748  138.887389  35.500056
# 33749  138.887444  35.500056
#
# [33750 rows x 15 columns]

# %% [markdown]
# ## 縦持ちデータから横持ちデータへの変換

# %% [markdown]
# 以上ですべての標高値にユニークな列番号と行番号が揃いました．
# 現在のデータフレーム`df`では`x`が列番号，`y`が行番号，`z`が標高値となっています．
# このように，データがってに並んでいる形式のことを縦持ちデータと呼びます．
#
#
# z|x|y
# -:|-:|-:
# 10.5|701902|603556
# 12.2|701903|603556
# 14.6|701904|603556
# 15.5|701902|603557
# 20.0|701903|603557
# 18.2|701904|603557
# 12.8|701902|603558
# 10.5|701903|603558
# 8.5|701904|603558
# $\vdots$|$\vdots$|$\vdots$
#
# ここで，`y`と`x`で`z`でピボットします．
# すると以下のような形式になります．
#
# yx|701902|701903|701904|$\ldots$
# -:|-:|-:|-:|-:
# 603556|10.5|12.2|14.6|$\ldots$
# 603557|15.5|20.0|18.2|$\ldots$
# 603558|12.8|10.5|8.5|$\ldots$
# $\vdots$|$\vdots$|$\vdots$|$\vdots$|$\ddots$
#
# これが横持ち形式のデータです．
# 座標と標高値の縦持ちデータを横持ちに変換するだけで
# DEMを作ることができます．
#
# 縦持ちを横持ちに変換するのは`pivot_table()`を使用します．
# 引数は行の値`index = 'y'`，
# 列の値`coluns = 'x'`，
# 行列に埋め込む値`values = 'z'`と
# 値がない部分に埋め込む値`fill_value = '-9999'`です．
# 値がない部分には`-9999`を埋め込みますので，
# 標高値が省略されている点もうまく対応することができます．
#
# 標高値を横持ちに変換したあとで，行名でソートします．

# %%
dem = df.pivot_table(index = 'y', columns = 'x', values = 'z', fill_value = -9999)
dem = dem.sort_index()
dem
# Out:
# x        699750   699751   699752   699753   699754   699755   699756  \
# y
# 577200   811.38   810.34   807.94   804.86   801.37   797.73   794.10
# 577201   813.12   812.25   809.93   806.92   803.58   799.99   796.08
# 577202   814.41   814.35   812.47   809.35   806.01   802.47   798.77
# 577203   814.99   815.65   814.50   812.04   808.83   805.32   801.42
# 577204   815.06   816.42   816.17   814.05   810.82   806.94   802.38
# ...         ...      ...      ...      ...      ...      ...      ...
# 577345  1017.41  1018.05  1017.15  1014.95  1010.10  1005.18  1000.20
# 577346  1022.28  1022.68  1022.26  1018.73  1013.30  1008.21  1002.95
# 577347  1027.56  1027.59  1026.65  1022.16  1016.57  1010.28  1004.00
# 577348  1033.03  1032.10  1028.63  1024.09  1017.99  1011.91  1004.71
# 577349  1036.83  1033.26  1027.63  1022.84  1017.74  1011.86  1007.76
#
# x        699757   699758  699759  ...  699965  699966  699967  699968  699969  \
# y                                 ...
# 577200   790.10   785.92  781.90  ...  630.80  630.88  631.00  630.99  630.38
# 577201   792.08   787.84  783.73  ...  630.79  630.81  631.00  630.98  630.56
# 577202   794.67   790.35  786.29  ...  630.72  630.69  630.67  630.52  629.40
# 577203   797.24   792.66  787.90  ...  630.84  630.73  630.51  630.00  629.49
# 577204   797.95   793.41  788.55  ...  630.89  630.78  630.61  630.27  629.87
# ...         ...      ...     ...  ...     ...     ...     ...     ...     ...
# 577345   995.23   990.02  985.14  ...  949.90  950.57  952.78  954.63  956.50
# 577346   997.15   991.31  985.99  ...  955.23  956.66  960.82  962.19  964.68
# 577347   997.25   992.44  988.38  ...  961.34  965.18  972.71  975.15  979.45
# 577348   999.93   996.89  993.04  ...  968.96  969.68  975.67  981.08  986.19
# 577349  1006.06  1001.40  996.77  ...  977.88  976.21  979.78  984.73  990.18
#
# x       699970  699971  699972  699973  699974
# y
# 577200  627.48  628.37  627.75  627.52  627.58
# 577201  627.90  628.01  627.97  627.79  627.80
# 577202  628.57  628.37  628.25  628.14  627.99
# 577203  629.05  628.76  628.53  628.48  628.42
# 577204  629.51  628.95  628.80  628.80  628.78
# ...        ...     ...     ...     ...     ...
# 577345  959.43  962.40  964.74  965.35  966.41
# 577346  970.40  970.62  970.19  970.25  970.36
# 577347  984.37  985.13  982.06  976.44  969.65
# 577348  989.25  988.40  984.11  975.90  967.77
# 577349  992.57  990.53  984.91  974.66  966.65
#
# [150 rows x 225 columns]

# %% [markdown]
# 以上でDEMが完成しました．
# 次にピボットした標高行列をnumpyのnp.ndarrayに変換します．
# これはGeoTiffとして保存するための準備です．

# %%
demp=dem.values.astype(np.float32)
demp
# Out:
# array([[ 811.38,  810.34,  807.94, ...,  627.75,  627.52,  627.58],
#        [ 813.12,  812.25,  809.93, ...,  627.97,  627.79,  627.8 ],
#        [ 814.41,  814.35,  812.47, ...,  628.25,  628.14,  627.99],
#        ...,
#        [1027.56, 1027.59, 1026.65, ...,  982.06,  976.44,  969.65],
#        [1033.03, 1032.1 , 1028.63, ...,  984.11,  975.9 ,  967.77],
#        [1036.83, 1033.26, 1027.63, ...,  984.91,  974.66,  966.65]],
#       dtype=float32)

# %% [markdown]
# ## DEMの図化

# %% [markdown]
# 作成したDEMを表示して確認してみましょう．

# %%
plt.figure(figsize = (10, 10))
im = plt.imshow(demp, cmap = "terrain",vmin = -10)
plt.colorbar(im)
plt.show()

# %% [markdown]
# # DEMをGeoTiffで保存する

# %% [markdown]
# GeoTiffで保存するためにはgdalライブラリを使います．
# まず，DEMのアフィンパラメーターを用意します．
# アフィンパラメーターは6個の実数のリストになります．
# 1個めはDEM全体の左側の座標，
# 2個めは標高値ひとつあたりの横方向のサイズ，
# 3個めは0で固定，
# 4個目はDEM全体の上側の座標，
# 5個目は0で固定，
# 6個目は標高値ひとつあたりの縦方向のサイズです．
#
# DEM全体の左側の座標は，`df['lon']`の最小値（西の端），
# 標高値ひとつあたりの横方向のサイズは`Xsize`，
# DEM全体の上側の座標は`df['lat']`の最大値（北の端），
# 標高値ひとつあたりの縦方向のサイズは`Ysize`になります．
# ただし，標高値ひとつあたりの縦方向のサイズは南方向になるので負になります．
#
# これらのパラメーターをリスト化し`trans`に格納します．

# %%
trans = [min(df['lon']), Xsize, 0, max(df['lat']), 0, -Ysize]
trans
# Out:
# [138.875, 5.555555555550503e-05, 0, 35.508333333, 0, -5.555555333335368e-05]

# %% [markdown]
# 次にDEMの座標系を指定します．
# GeoTiffで保存するためには，空間参照系を表すオブジェクト`osr.SpatialRefernece()`を作成し，
# これにEPSGコードで空間参照系を設定します．
# 基盤地図情報のDEMはJGD2011の緯度経度座標系（地理座標系）で，
# EPSGが`4612`になりますので，以下のような設定になります．

# %%
srs = osr.SpatialReference()
srs.ImportFromEPSG(4612)
# Out:
# 0

# %% [markdown]
# 次に書き出しの設定をします．
# GeoTiffで保存するためには`gdal.GetDriverByName`型のオブジェクトを作り，
# ここでファイル形式を指定します．
# 次に`Create`メソッドを使ってファイルを生成します．
# `Create`メソッドの引数は，保存ファイル名，画像の縦サイズ，画像の横サイズ，バンド数，格納する配列の型です．
#
# 縦横サイズは`demp.shape`で取得できます．
# `demp.shape[1]`が縦サイズ，`demp.shape[0]`が横サイズです．
# バンド数はDEMが一つだけなので`1`です．
# 配列`demp`を保存しますので，データ型は32ビット浮動小数点型になります．

# %%
driver = gdal.GetDriverByName('GTiff')
output = driver.Create(base_dir + 'test.tif', demp.shape[1], demp.shape[0], 1, gdal.GDT_Float32)

# %% [markdown]
# 標高の配列，設定した参照座標系などをオブジェクトに書き込みます．
# また，データなしの値を`-9999`に設定します．

# %%
output.GetRasterBand(1).WriteArray(demp)
output.GetRasterBand(1).SetNoDataValue(-9999)
output.SetGeoTransform(trans)
output.SetProjection(srs.ExportToWkt())
# Out:
# 0

# %% [markdown]
# 最後にキャッシュをすべて書き出し，オブジェクトを削除して終了です．

# %%
output.FlushCache()
output = None

# %% [markdown]
# # 作成したDEMの投影変換

# %% [markdown]
# 保存したGeoTiffは緯度経度座標系なので，
# 平面直角座標系に投影変換をします．
# `gdal.Warp`を使えば投影変換ができます．
#
# 以下を試して見てください．

# %%
opt = gdal.WarpOptions(dstSRS = 'EPSG:6677', srcNodata = -9999, dstNodata = -9999, outputType=gdal.GDT_Float32, xRes = 5.0, yRes = 5.0, resampleAlg = 'bilinear')
demnew = gdal.Warp(base_dir + 'miyake_dem_JGD2011_reprojected.tif', base_dir + 'miyake_dem_JGD2011_latlon.tif', options = opt)
demnew.FlushCache()
denew = None

# %% [markdown]
# # 全部入りのプログラム

# %% [markdown]
# 以下が全部入りのプログラムです．
# ディレクトリ内にあるすべての基盤地図情報DEMのXMLファイルを自動的に読み込み，
# つなぎ合わせてGeoTiffで書き出します．
#
# ディレクトリ内のすべてのXMLファイルを処理する部分では，
# `glob`とループで逐次処理を行っています．
# ファイルごとに縦持ちの標高データ`df`を作成しそれを`dfall`に追加することで，
# 処理対象のXMLから取得したすべての標高値を`dfall`に格納しています．
# 最後に`dfall`を横持ちに変換することで
# ファイルの結合をしています．

# %%
import xml.etree.ElementTree as ET
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import glob
import pandas as pd
import io
from tqdm import tqdm
import time
from osgeo import gdal, gdalconst, gdal_array, osr
#from google.colab import drive

#drive.mount('/content/drive')
base_dir = "./"

ns = {'default': 'http://fgd.gsi.go.jp/spec/2008/FGD_GMLSchema',
  'xlink': 'http://www.w3.org/1999/xlink',
  'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
  'gml': 'http://www.opengis.net/gml/3.2'}

infiles = glob.glob(base_dir + '/GSI-DEM2/*.xml')

dfall = pd.DataFrame()

# ここからループしてすべてのXMLファイルを変換する

for infile in tqdm(infiles):
  tree = ET.parse(infile)
  elem = tree.getroot()

  lowercorner = elem.find('.//gml:lowerCorner', ns)
  uppercorner = elem.find('.//gml:upperCorner', ns)

  tuplelist = elem.find(".//gml:tupleList", ns)
  df = pd.read_csv(io.StringIO(tuplelist.text), header = None)
  df.columns = ['att', 'z']

  startPoint = elem.find('.//gml:startPoint', ns).text.split(' ')
  startPointX = int(startPoint[0])
  startPointY = int(startPoint[1])

  cols = int(elem.find(".//gml:high", ns).text.split(' ')[0]) + 1
  rows = int(elem.find(".//gml:high", ns).text.split(' ')[1]) + 1

  start = startPointX + (cols * startPointY)
  end = int(df.shape[0]) + start

  df['n'] = list(range(start, end))
  df['x4'] = (df['n'] % cols)
  df['y4'] = (df['n'] // cols)

  uppercorner = elem.find('.//gml:upperCorner', ns)
  lowercorner = elem.find('.//gml:lowerCorner', ns)

  ULX = float(lowercorner.text.split(' ')[1])
  ULY = float(uppercorner.text.split(' ')[0])
  LRX = float(uppercorner.text.split(' ')[1])
  LRY = float(lowercorner.text.split(' ')[0])

  mesh = elem.find('.//default:mesh', ns)
  
  df['y1'] = int(mesh.text[0:2])
  df['x1'] = int(mesh.text[2:4])
  df['y2'] = int(mesh.text[4])
  df['x2'] = int(mesh.text[5])
  df['y3'] = int(mesh.text[6])
  df['x3'] = int(mesh.text[7])

  df['x'] = df['x4'] + (df['x3'] * cols) + (df['x2'] * 10 * cols) + (df['x1'] * 8 * 10 * cols)
  df['y'] = df['y4'] + ((8 - df['y3']) * rows) + ((10 - df['y2']) * 10 * rows) + ((100 - df['y1']) * 8 * 10 * rows)

  Xsize = (LRX - ULX) / cols
  Ysize = (ULY - LRY) / rows

  df['lon'] = ULX + df['x4'] * Xsize
  df['lat'] = ULY - df['y4'] * Ysize

#  dfall = dfall.append(df)
  dfall = pd.concat([dfall, df])

# データがない部分用のダミーデータを作る
d1 = pd.DataFrame()
d2 = pd.DataFrame()

d1['x'] = list(range(min(dfall['x']), max(dfall['x'])))
d1['y'] = min(dfall['y'])
d1['z'] = -9999
d2['x'] = min(dfall['x'])
d2['y'] = list(range(min(dfall['y']), max(dfall['y'])))
d2['z'] = -9999

# ダミーデータを標高の入っているデータフレームに結合する
#dfall = dfall.append(d1).append(d2)
dfall = pd.concat([dfall, d1, d2])

# 縦持ちデータを横持ちにピボットする
# データなしと標高値が重なる場合があるので，その場合は最大値（すなわち標高値）を残す
dem = dfall.pivot_table(index = 'y', columns = 'x', values = 'z', fill_value = -9999, aggfunc = 'max')
dem = dem.sort_index()

# 横持ちにした標高値を32ビット浮動小数点型のnp.Arrayに変換する
demp = dem.values.astype(np.float32)

# 確認のためDEMを図化する
plt.figure(figsize = (10, 10))
im = plt.imshow(demp, cmap = "terrain",vmin = -10)
plt.colorbar(im)
plt.show()

# GeoTiff書き出しのためのアフィンパラメータの設定（北西端の座標，メッシュサイズなど）
trans = [min(dfall['lon']), Xsize, 0, max(dfall['lat']), 0, -Ysize]

# 座標系の設定（EPSG:4612，JGD2000の緯度経度座標系）
srs = osr.SpatialReference()
srs.ImportFromEPSG(4612)

# GeoTiff書き出しのための準備，オブジェクトの生成と初期化
driver = gdal.GetDriverByName('GTiff')
output = driver.Create(base_dir + 'tanzawa_dem_JGD2011_latlon.tif', demp.shape[1], demp.shape[0], 1, gdal.GDT_Float32)
output.GetRasterBand(1).WriteArray(demp)
output.GetRasterBand(1).SetNoDataValue(-9999)
output.SetGeoTransform(trans)
output.SetProjection(srs.ExportToWkt())
output.FlushCache()
output = None

# DEMをEPSG:6677（JGD2011第9系）に投影変換して保存する
opt = gdal.WarpOptions(dstSRS = 'EPSG:6677', srcNodata = -9999, dstNodata = -9999, outputType=gdal.GDT_Float32, xRes = 5.0, yRes = 5.0, resampleAlg = 'bilinear')
demnew = gdal.Warp(base_dir + 'tanzawa_dem_JGD2011_reprojected.tif', base_dir + 'tanzawa_dem_JGD2011_latlon.tif', options = opt)
demnew.FlushCache()
denew = None
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 15.64it/s]
